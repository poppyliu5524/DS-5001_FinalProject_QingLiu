# %% [markdown]
# # Metadata
#
# ```yaml
# Course:   DS 5001
# Module:   04 Lab
# Topic:    NLP and the Pipeline
# Author:   R.C. Alvarado
# Date:     5 February 2023
# ```
#
# **Purpose**:  We import a collection of texts and convert to F2. Then we annotate the collection to create an F3-level model.

# %% [markdown]
# # Set Up

# %%
data_home = "/Users/poppy/Documents/TeachSim Project/Robertson_Semantic/Data"
local_lib = "/Users/poppy/Documents/TeachSim Project/Robertson_Semantic/lib"

# %%
import os
import pandas as pd
import numpy as np
from glob import glob
import re
import nltk
import plotly_express as px

# %% [markdown]
# ## Create Lib

# %%
def create_library_df(main_folder):
    data = []

    for root, _, files in os.walk(main_folder):
        for file in files:
            if file.endswith('.txt'):  # Check if it's a plain text file
                file_path = os.path.join(root, file)
                subfolder = os.path.relpath(root, main_folder)
                file_name = os.path.splitext(file)[0]
                data.append((file_path, file_name, subfolder))

    columns = ['File Path', 'document_id', 'Subfolder']
    df = pd.DataFrame(data, columns=columns)

    return df

# %%
main_folder = '/Users/poppy/Documents/TeachSim Project/Robertson_Semantic/Data'
df = create_library_df(main_folder)

# %%
df[['site_id', 'scenario_id']] = df['Subfolder'].str.split('/', expand=True)

# %%
LIB = df.drop('Subfolder', axis=1).set_index('document_id')
LIB
# Out:
#                                                         File Path site_id  \
# document_id
# 02_004_22c_100  /Users/poppy/Documents/TeachSim Project/Robert...     SMU
# 02_004_22c_074  /Users/poppy/Documents/TeachSim Project/Robert...     SMU
# 02_004_22c_061  /Users/poppy/Documents/TeachSim Project/Robert...     SMU
# 02_004_22c_049  /Users/poppy/Documents/TeachSim Project/Robert...     SMU
# 02_004_32c_014  /Users/poppy/Documents/TeachSim Project/Robert...     SMU
# ...                                                           ...     ...
# 01_004_12c_022  /Users/poppy/Documents/TeachSim Project/Robert...     UVA
# 01_004_12c_023  /Users/poppy/Documents/TeachSim Project/Robert...     UVA
# 01_004_12c_037  /Users/poppy/Documents/TeachSim Project/Robert...     UVA
# 01_004_12c_035  /Users/poppy/Documents/TeachSim Project/Robert...     UVA
# 01_004_12c_008  /Users/poppy/Documents/TeachSim Project/Robert...     UVA
#
#                scenario_id
# document_id
# 02_004_22c_100          CN
# 02_004_22c_074          CN
# 02_004_22c_061          CN
# 02_004_22c_049          CN
# 02_004_32c_014          CN
# ...                    ...
# 01_004_12c_022          QF
# 01_004_12c_023          QF
# 01_004_12c_037          QF
# 01_004_12c_035          QF
# 01_004_12c_008          QF
#
# [214 rows x 3 columns]

# %% [markdown]
# ## Build Corpus

# %%
import os
import glob
import pandas as pd

main_folder = '/Users/poppy/Documents/TeachSim Project/Robertson_Semantic/Data'

# Traverse all subfolders and read text files
documents = []

for root, dirs, files in os.walk(main_folder):
    for file in files:
        if file.endswith(".txt"):
            filepath = os.path.join(root, file)
            with open(filepath, 'r', encoding='utf-8') as f:
                content = f.read()
                paragraphs = content.split('\n\n')
                documents.append({'document_id': os.path.splitext(file)[0], 'content': content})

# Convert the list of dictionaries to a DataFrame
corpus = pd.DataFrame(documents)

# %%
#remove "transcripted by ..."
# Function to remove the "Transcribed by https://otter.ai" text
def remove_transcription_info(text):
    return text.replace("Transcribed by https://otter.ai", "")

# Remove the text from the content column
corpus['content'] = corpus['content'].apply(remove_transcription_info)

# %%
corpus
# Out:
#         document_id                                            content
# 0    02_004_22c_100  Kristyn  0:00  \nSo okay, tell me how did you ...
# 1    02_004_22c_074  Anna  0:00  \nsimulation. Okay. Thanks so much...
# 2    02_004_22c_061  Teacher  0:00  \n Oh my gosh, that was so fun....
# 3    02_004_22c_049  COACH  0:00  \nHow'd you feel about that simul...
# 4    02_004_32c_014  Coach  0:00  \nHow did you feel about that one...
# ..              ...                                                ...
# 209  01_004_12c_022  Teacher  0:00  \nSorry\n\nCoach  0:01  \nOh, y...
# 210  01_004_12c_023  Coach  0:01  \nHey, how did that go for you? H...
# 211  01_004_12c_037  Coach  0:01  \nSo how did that go for you?\n\n...
# 212  01_004_12c_035  Coach  0:00  \nOkay. Alright, so how did that ...
# 213  01_004_12c_008  Coach  0:00  \nSo how did he go?\n\nTeacher  0...
#
# [214 rows x 2 columns]

# %% [markdown]
# ## Use NLTK to Chunk Sentence and Parse Tokens

# %%
import pandas as pd
import re
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/poppy/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
from nltk import pos_tag

# %%
#define ohco
ohco = ['document_id', 'paragraph_id', 'sentence_id', 'token_id']

# %% [markdown]
# ## Parse text into paragraphs

# %%
import regex
import pandas as pd

# %%
def parse_content(text):
    lines = text.split('\n')
    parsed_data = []
    current_speaker = None
    current_timestamp = None
    current_content = []
    previous_line_empty = True
    
    for line in lines:
        if not line.strip():
            previous_line_empty = True
            continue
        
        if previous_line_empty:
            match = regex.search(r'^(\w.+?)\s{1,2}(\d+:\d+)(.*)$', line)
            if match:
                if current_speaker is not None:
                    parsed_data.append((current_speaker, current_timestamp, ' '.join(current_content)))
                    
                current_speaker = match.group(1)
                current_timestamp = match.group(2)
                current_content = [match.group(3).strip()]
                previous_line_empty = False
                continue
        
        current_content.append(line.strip())
        previous_line_empty = False
    
    if current_speaker is not None:
        parsed_data.append((current_speaker, current_timestamp, ' '.join(current_content)))
        
    return parsed_data

# %%
parsed_data = []

for index, row in corpus.iterrows():
    document_id = row['document_id']
    content = row['content']
    parsed_paragraphs = parse_content(content)
    
    for speaker, timestamp, paragraph in parsed_paragraphs:
        parsed_data.append((document_id, speaker, timestamp, paragraph))

# %%
PARA = pd.DataFrame(parsed_data, columns=['document_id', 'speaker', 'timestamp', 'content'])
PARA['paragraph_id'] = PARA.groupby('document_id').cumcount() + 1
PARA = PARA[['document_id', 'paragraph_id', 'content', 'speaker', 'timestamp']]

# %%
PARA['speaker'].unique()
##So this format look good to me
# Out:
# array(['Kristyn', 'Teacher', 'Anna', 'COACH', 'TEACHER', 'Coach',
#        'Unknown Speaker', 'coach', 'Jamie', 'Participant', 'Jasmine',
#        'Participantr', 'Speaker 1', 'TeachSIM Staff', 'TeachSIM',
#        'Participant ', 'Sim Staff', 'Jamie McLemore', 'Ethan'],
#       dtype=object)

# %%
PARA
# Out:
#          document_id  paragraph_id  \
# 0     02_004_22c_100             1
# 1     02_004_22c_100             2
# 2     02_004_22c_100             3
# 3     02_004_22c_100             4
# 4     02_004_22c_100             5
# ...              ...           ...
# 4328  01_004_12c_008            22
# 4329  01_004_12c_008            23
# 4330  01_004_12c_008            24
# 4331  01_004_12c_008            25
# 4332  01_004_12c_008            26
#
#                                                 content  speaker timestamp
# 0      So okay, tell me how did you feel about that?...  Kristyn      0:00
# 1      I mean, like, is there anything that I can li...  Teacher      0:05
# 2      Yeah, I think that's a fair question. Um, I t...  Kristyn      0:13
# 3      Um, well, the more specific you are, the less...  Teacher      1:29
# 4      Totally. If we think back to that scenario th...  Kristyn      1:39
# ...                                                 ...      ...       ...
# 4328   That's true. It does say that good reading. I...  Teacher      5:37
# 4329   Oh, well, in paragraph 20. It says her heart ...    Coach      5:44
# 4330   Yeah, maybe because people do have their hear...  Teacher      5:54
# 4331   It says that... great job there. Great job fo...    Coach      6:04
# 4332                                         I am ready  Teacher      6:26
#
# [4333 rows x 5 columns]

# %% [markdown]
# ## Chunk into sentence

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/poppy/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Split paragraphs into sentences
PARA['sentences'] = PARA['content'].apply(nltk.sent_tokenize)

# Explode the sentences column
SENT = PARA.explode('sentences')

# Create sentence_id within each paragraph
SENT['sentence_id'] = SENT.groupby(['document_id', 'paragraph_id']).cumcount() + 1

# Rearrange columns and set hierarchical index
SENT = SENT[['document_id', 'paragraph_id', 'sentence_id', 'sentences', 'speaker']]

# %%
SENT
# Out:
#          document_id  paragraph_id  sentence_id  \
# 0     02_004_22c_100             1            1
# 0     02_004_22c_100             1            2
# 0     02_004_22c_100             1            3
# 1     02_004_22c_100             2            1
# 2     02_004_22c_100             3            1
# ...              ...           ...          ...
# 4331  01_004_12c_008            25            4
# 4331  01_004_12c_008            25            5
# 4331  01_004_12c_008            25            6
# 4331  01_004_12c_008            25            7
# 4332  01_004_12c_008            26            1
#
#                                               sentences  speaker
# 0         So okay, tell me how did you feel about that?  Kristyn
# 0                           Just give me your thoughts.  Kristyn
# 0                                         You can vent.  Kristyn
# 1      I mean, like, is there anything that I can li...  Teacher
# 2                 Yeah, I think that's a fair question.  Kristyn
# ...                                                 ...      ...
# 4331                         I think that you're on it.    Coach
# 4331     I think that you're ready for your next round.    Coach
# 4331                                              Wait.    Coach
# 4331  Are you ready to dive in to the second round o...    Coach
# 4332                                         I am ready  Teacher
#
# [15006 rows x 5 columns]

# %% [markdown]
# ## Expand contractions

# %%
# pip install contractions

# %%
import contractions

# %%
# Define the expand_contractions function
def expand_contractions(text):
    return contractions.fix(text)

# Apply the function to the "sentence" column
SENT['sentences'] = SENT['sentences'].apply(expand_contractions)

# %% [markdown]
# ## Tokenize sentence

# %%
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /Users/poppy/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/poppy/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
def custom_tokenize(sentence):
    pattern = r'\w+\'\w+|\w+'
    tokens = nltk.regexp_tokenize(sentence, pattern)
    pos_tagged_tokens = pos_tag(tokens)
    return pos_tagged_tokens

# %%
# Tokenize sentences and remove punctuations
SENT['tokens'] = SENT['sentences'].apply(custom_tokenize)

# Explode the tokens column
TOKENS = SENT.explode('tokens')

# Generate term_id for each token within a sentence
TOKENS['token_id'] = TOKENS.groupby(['document_id', 'paragraph_id', 'sentence_id']).cumcount() + 1

# Separate term_str and POS from pos_tuple
# Add term_str and POS columns
TOKENS = TOKENS.reset_index(drop=True)
def extract_term_str(token):
    if isinstance(token, tuple):
        return token[0]
    else:
        return None

def extract_pos(token):
    if isinstance(token, tuple):
        return token[1]
    else:
        return None

TOKENS['term_str'] = TOKENS['tokens'].apply(extract_term_str)
TOKENS['POS'] = TOKENS['tokens'].apply(extract_pos)


# Rearrange columns and set hierarchical index
TOKENS = TOKENS[['document_id', 'paragraph_id', 'sentence_id', 'token_id', 'term_str', 'POS', 'speaker']]
TOKENS = TOKENS.set_index(ohco)

# %%
TOKENS
# Out:
#                                                     term_str  POS  speaker
# document_id    paragraph_id sentence_id token_id
# 02_004_22c_100 1            1           1                 So   RB  Kristyn
#                                         2               okay   RB  Kristyn
#                                         3               tell   VB  Kristyn
#                                         4                 me  PRP  Kristyn
#                                         5                how  WRB  Kristyn
# ...                                                      ...  ...      ...
# 01_004_12c_008 25           7           12               the   DT    Coach
#                                         13        simulation   NN    Coach
#                26           1           1                  I  PRP  Teacher
#                                         2                 am  VBP  Teacher
#                                         3              ready   JJ  Teacher
#
# [200702 rows x 3 columns]

# %% [markdown]
# ## Build a classfier for coaches versus preservice teacher

# %%
TOKENS['speaker'].unique()
# Out:
# array(['Kristyn', 'Teacher', 'Anna', 'COACH', 'TEACHER', 'Coach',
#        'Unknown Speaker', 'coach', 'Jamie', 'Participant', 'Jasmine',
#        'Participantr', 'Speaker 1', 'TeachSIM Staff', 'TeachSIM',
#        'Participant ', 'Sim Staff', 'Jamie McLemore', 'Ethan'],
#       dtype=object)

# %%
coach_names = ['Kristyn', 'Anna', 'COACH', 'Coach', 'coach', 
               'Jamie', 'Jasmine', 'TeachSIM Staff', 'TeachSIM', 
               'Sim Staff', 'Jamie McLemore']

# %%
TOKENS['coach_flag'] = TOKENS['speaker'].apply(lambda x: 1 if x in coach_names else 0)

# %%
TOKENS
# Out:
#                                                     term_str  POS  speaker  \
# document_id    paragraph_id sentence_id token_id
# 02_004_22c_100 1            1           1                 So   RB  Kristyn
#                                         2               okay   RB  Kristyn
#                                         3               tell   VB  Kristyn
#                                         4                 me  PRP  Kristyn
#                                         5                how  WRB  Kristyn
# ...                                                      ...  ...      ...
# 01_004_12c_008 25           7           12               the   DT    Coach
#                                         13        simulation   NN    Coach
#                26           1           1                  I  PRP  Teacher
#                                         2                 am  VBP  Teacher
#                                         3              ready   JJ  Teacher
#
#                                                   coach_flag
# document_id    paragraph_id sentence_id token_id
# 02_004_22c_100 1            1           1                  1
#                                         2                  1
#                                         3                  1
#                                         4                  1
#                                         5                  1
# ...                                                      ...
# 01_004_12c_008 25           7           12                 1
#                                         13                 1
#                26           1           1                  0
#                                         2                  0
#                                         3                  0
#
# [200702 rows x 4 columns]

# %% [markdown]
# # Add some information to LIB

# %% [markdown]
# ### number of paragraphs, sentences, words, terms in each document

# %%
LIB['doc_length'] = TOKENS.groupby('document_id').term_str.count()

# %%
# Count the number of paragraphs within each document_id
LIB['n_paragraph'] = TOKENS.reset_index().groupby('document_id')['paragraph_id'].nunique()

# %%
#number of unique words within each document
LIB['n_word'] = TOKENS.groupby('document_id').term_str.nunique()

# %%
LIB
# Out:
#                                                         File Path site_id  \
# document_id
# 02_004_22c_100  /Users/poppy/Documents/TeachSim Project/Robert...     SMU
# 02_004_22c_074  /Users/poppy/Documents/TeachSim Project/Robert...     SMU
# 02_004_22c_061  /Users/poppy/Documents/TeachSim Project/Robert...     SMU
# 02_004_22c_049  /Users/poppy/Documents/TeachSim Project/Robert...     SMU
# 02_004_32c_014  /Users/poppy/Documents/TeachSim Project/Robert...     SMU
# ...                                                           ...     ...
# 01_004_12c_022  /Users/poppy/Documents/TeachSim Project/Robert...     UVA
# 01_004_12c_023  /Users/poppy/Documents/TeachSim Project/Robert...     UVA
# 01_004_12c_037  /Users/poppy/Documents/TeachSim Project/Robert...     UVA
# 01_004_12c_035  /Users/poppy/Documents/TeachSim Project/Robert...     UVA
# 01_004_12c_008  /Users/poppy/Documents/TeachSim Project/Robert...     UVA
#
#                scenario_id  doc_length  n_paragraph  n_word
# document_id
# 02_004_22c_100          CN         804           12     283
# 02_004_22c_074          CN        1093           17     355
# 02_004_22c_061          CN        1033           22     318
# 02_004_22c_049          CN        1012           35     324
# 02_004_32c_014          CN        1102           21     342
# ...                    ...         ...          ...     ...
# 01_004_12c_022          QF         897           10     271
# 01_004_12c_023          QF         842           15     268
# 01_004_12c_037          QF        1010           36     285
# 01_004_12c_035          QF        1268           50     338
# 01_004_12c_008          QF        1082           26     320
#
# [214 rows x 6 columns]

# %% [markdown]
# ## Descriptive Statistics about Corpus

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=LIB, x='scenario_id', y='doc_length', hue='site_id', estimator=np.mean)
plt.title("Average Document Length by Site and Scenario")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=LIB, x='scenario_id', y='n_paragraph', hue='site_id', estimator=np.mean)
plt.title("Average Number of Conversations by Site and Scenario")
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=LIB, x='scenario_id', y='n_word', hue='site_id', estimator=np.mean)
plt.title("Average Number of Conversations by Site and Scenario")
plt.show()

# %% [markdown]
# # Exract VOCAB
#
# Extract a vocabulary from the CORPUS as a whole

# %%
empty_rows = TOKENS['term_str'].isnull().sum()

# %%
empty_rows
# Out:
# 1

# %%
TOKENS = TOKENS[TOKENS.term_str != '']

# %%
VOCAB = TOKENS.term_str.value_counts().to_frame('n')
VOCAB.index.name = 'term_str'
VOCAB['p'] = VOCAB.n / VOCAB.n.sum()
VOCAB['i'] = -np.log2(VOCAB.p)
VOCAB['n_chars'] = VOCAB.index.str.len()

# %%
VOCAB
# Out:
#                    n         p          i  n_chars
# term_str
# you             7732  0.038525   4.698062        3
# to              7249  0.036118   4.791122        2
# that            6546  0.032616   4.938290        4
# I               6008  0.029935   5.062019        1
# the             5625  0.028027   5.157051        3
# ...              ...       ...        ...      ...
# timed              1  0.000005  17.614688        5
# spots              1  0.000005  17.614688        5
# perspectives       1  0.000005  17.614688       12
# checking           1  0.000005  17.614688        8
# individualized     1  0.000005  17.614688       14
#
# [4137 rows x 4 columns]

# %% [markdown]
# ## Add Max POS

# %%
VOCAB['max_pos'] = TOKENS[['term_str','POS']].value_counts().unstack(fill_value=0).idxmax(1)

# %%
VOCAB
# Out:
#                    n         p          i  n_chars max_pos
# term_str
# you             7732  0.038525   4.698062        3     PRP
# to              7249  0.036118   4.791122        2      TO
# that            6546  0.032616   4.938290        4      IN
# I               6008  0.029935   5.062019        1     PRP
# the             5625  0.028027   5.157051        3      DT
# ...              ...       ...        ...      ...     ...
# timed              1  0.000005  17.614688        5     VBN
# spots              1  0.000005  17.614688        5     NNS
# perspectives       1  0.000005  17.614688       12     NNS
# checking           1  0.000005  17.614688        8     VBG
# individualized     1  0.000005  17.614688       14      JJ
#
# [4137 rows x 5 columns]

# %% [markdown]
# ## Compute POS ambiguity
#
# How many POS categories are associated with each word?

# %%
VOCAB['n_pos'] = TOKENS[['term_str','POS']].value_counts().unstack().count(1)

# %%
VOCAB['cat_pos'] = TOKENS[['term_str','POS']].value_counts().to_frame('n').reset_index()\
    .groupby('term_str').POS.apply(lambda x: set(x))

# %%
VOCAB
# Out:
#                    n         p          i  n_chars max_pos  n_pos  \
# term_str
# you             7732  0.038525   4.698062        3     PRP      1
# to              7249  0.036118   4.791122        2      TO      1
# that            6546  0.032616   4.938290        4      IN      6
# I               6008  0.029935   5.062019        1     PRP      1
# the             5625  0.028027   5.157051        3      DT      1
# ...              ...       ...        ...      ...     ...    ...
# timed              1  0.000005  17.614688        5     VBN      1
# spots              1  0.000005  17.614688        5     NNS      1
# perspectives       1  0.000005  17.614688       12     NNS      1
# checking           1  0.000005  17.614688        8     VBG      1
# individualized     1  0.000005  17.614688       14      JJ      1
#
#                                   cat_pos  stop
# term_str
# you                                 {PRP}     1
# to                                   {TO}     1
# that            {WDT, DT, WP, IN, RB, VB}     1
# I                                   {PRP}     0
# the                                  {DT}     1
# ...                                   ...   ...
# timed                               {VBN}     0
# spots                               {NNS}     0
# perspectives                        {NNS}     0
# checking                            {VBG}     0
# individualized                       {JJ}     0
#
# [4137 rows x 8 columns]

# %% [markdown]
# ## Add Stopwords

# %% [markdown]
# We use NLTK's built in stopword list for English. Note that we can add and subtract from this list, or just create our own list and keep it in our data model.

# %%
sw = pd.DataFrame(nltk.corpus.stopwords.words('english'), columns=['term_str'])
sw = sw.reset_index().set_index('term_str')
sw.columns = ['dummy']
sw.dummy = 1

# %%
VOCAB['stop'] = VOCAB.index.map(sw.dummy)
VOCAB['stop'] = VOCAB['stop'].fillna(0).astype('int')

# %%
VOCAB[VOCAB.stop == 1].sample(10)
# Out:
#              n         p          i  n_chars max_pos  n_pos cat_pos  stop
# term_str
# each        36  0.000179  12.444763        4      DT      1    {DT}     1
# if         725  0.003612   8.112851        2      IN      1    {IN}     1
# your       811  0.004041   7.951130        4    PRP$      1  {PRP$}     1
# those      290  0.001445   9.434779        5      DT      1    {DT}     1
# some       269  0.001340   9.543226        4      DT      1    {DT}     1
# then       912  0.004544   7.781798        4      RB      1    {RB}     1
# itself       5  0.000025  15.292760        6     PRP      1   {PRP}     1
# into       270  0.001345   9.537873        4      IN      1    {IN}     1
# me        1061  0.005286   7.563479        2     PRP      1   {PRP}     1
# through    119  0.000593  10.719871        7      IN      1    {IN}     1

# %% [markdown]
# ## Interlude: Stopword Stats

# %%
a = VOCAB.groupby('stop').n_chars.mean()
b = VOCAB.groupby('stop').n_pos.mean().sort_values(ascending=False)

# %%
pd.concat([a,b], axis=1)
# Out:
#        n_chars     n_pos
# stop
# 0     6.693400  1.442341
# 1     3.844262  1.622951

# %%
VOCAB.groupby('n_chars').n_pos.mean()\
    .sort_values(ascending=False).plot(style='o');

# %% [markdown]
# Curious that stopwords would have such variability.

# %%
VOCAB[VOCAB.stop == True].sort_values('n_pos', ascending=False)[['n_pos','cat_pos']].head(20)
# Out:
#           n_pos                     cat_pos
# term_str
# do            6  {VBP, NN, IN, VB, JJ, VBN}
# that          6   {WDT, DT, WP, IN, RB, VB}
# so            6  {VBP, IN, RB, CC, VB, NNS}
# off           5        {NN, IN, RB, RP, JJ}
# about         4            {RP, IN, NN, RB}
# down          4            {IN, RB, RP, JJ}
# all           4           {PDT, DT, VB, RB}
# over          4            {IN, NN, RB, RP}
# have          4           {VBP, NN, VB, JJ}
# what          4          {WDT, VBP, VB, WP}
# up            4           {IN, VBP, RB, RP}
# no            3                {DT, RB, UH}
# myself        3               {NN, VB, PRP}
# yourself      3               {NN, VB, PRP}
# once          3                {IN, RB, JJ}
# further       3               {RBR, RB, JJ}
# while         3                {IN, NN, VB}
# because       3               {IN, VBP, RB}
# both          3               {VBP, DT, CC}
# there         3                {EX, RB, JJ}

# %% [markdown]
# ## Add Stems

# %%
from nltk.stem.porter import PorterStemmer
stemmer1 = PorterStemmer()
VOCAB['stem_porter'] = VOCAB.apply(lambda x: stemmer1.stem(x.name), 1)

from nltk.stem.snowball import SnowballStemmer
stemmer2 = SnowballStemmer("english")
VOCAB['stem_snowball'] = VOCAB.apply(lambda x: stemmer2.stem(x.name), 1)

from nltk.stem.lancaster import LancasterStemmer
stemmer3 = LancasterStemmer()
VOCAB['stem_lancaster'] = VOCAB.apply(lambda x: stemmer3.stem(x.name), 1)

# %%
VOCAB.sample(10)
# Out:
#              n         p          i  n_chars max_pos  n_pos        cat_pos  \
# term_str
# corrected    5  0.000025  15.292760        9     VBD      2     {VBN, VBD}
# optional     2  0.000010  16.614688        8      JJ      1           {JJ}
# books        6  0.000030  15.029726        5     NNS      1          {NNS}
# nicer        2  0.000010  16.614688        5      NN      2       {NN, VB}
# teacher's    1  0.000005  17.614688        9      JJ      1           {JJ}
# inference   18  0.000090  13.444763        9      NN      1           {NN}
# style        2  0.000010  16.614688        5      NN      1           {NN}
# very       293  0.001460   9.419931        4      RB      3  {VBP, RB, JJ}
# 97           1  0.000005  17.614688        2      CD      1           {CD}
# nobody's     2  0.000010  16.614688        8      MD      2       {MD, NN}
#
#            stop stem_porter stem_snowball stem_lancaster
# term_str
# corrected     0     correct       correct        correct
# optional      0      option        option            opt
# books         0        book          book           book
# nicer         0       nicer         nicer            nic
# teacher's     0    teacher'       teacher      teacher's
# inference     0       infer         infer            inf
# style         0       style         style           styl
# very          1        veri          veri           very
# 97            0          97            97             97
# nobody's      0     nobody'        nobodi       nobody's

# %% [markdown]
# # Save

# %%
out_path = f'{data_home}/output/'

# %%
LIB.to_csv(f'{out_path}/LIB.csv')
VOCAB.to_csv(f'{out_path}/VOCAB.csv')
TOKENS.to_csv(f'{out_path}/CORPUS.csv')
