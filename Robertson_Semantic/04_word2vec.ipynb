# %% [markdown]
# # Metadata
#
# ```yaml
# Topic:     Word2Vec
# Author:    Qing Liu
# Date:      04/30/2023
# ```
#
# **Purpose:** We create word embeddings with transcripts data using word2vec and visualize results with tSNE.

# %% [markdown]
# # Set Up

# %%
data_in = '/Users/poppy/Documents/TeachSim Project/Robertson_Semantic/Data/output'
data_out = '/Users/poppy/Documents/TeachSim Project/Robertson_Semantic/Data/output'
local_lib = '/Users/poppy/Documents/TeachSim Project/Robertson_Semantic/lib'

# %%
OHCO = OHCO = ['document_id', 'paragraph_id', 'sentence_id', 'token_id']
PARA = OHCO[:2] # Paragraphs
SENT = OHCO[:3] # Sentences
BAG = PARA

# %%
# word2vec parameters
w2v_params = dict(
    window = 5,
    vector_size = 200,
    min_count = 30,
    workers = 4
)

# %%
import pandas as pd
import numpy as np
from gensim.models import word2vec
from sklearn.manifold import TSNE
import plotly_express as px

# %% [markdown]
# # Import `TOKENS` and convert to `DOCS` for Gensim
#
# We import data from the TOKEN table of the novels corpus, excluding proper nouns.

# %%
TOKENS = pd.read_csv(f'{data_in}/CORPUS.csv').set_index(OHCO)

# %%
VOCAB = pd.read_csv(f'{data_in}/VOCAB.csv').set_index('term_str')

# %%
TOKENS.head()
# Out:
#                                                   term_str  POS  speaker  \
# document_id    paragraph_id sentence_id token_id
# 02_004_22c_100 1            1           3             tell   VB  Kristyn
#                                         8             feel   VB  Kristyn
#                             2           2             give   VB  Kristyn
#                                         5         thoughts  NNS  Kristyn
#                             3           3             vent   VB  Kristyn
#
#                                                   coach_flag  stopword_flag  \
# document_id    paragraph_id sentence_id token_id
# 02_004_22c_100 1            1           3                  1              0
#                                         8                  1              0
#                             2           2                  1              0
#                                         5                  1              0
#                             3           3                  1              0
#
#                                                   unimportant_flag
# document_id    paragraph_id sentence_id token_id
# 02_004_22c_100 1            1           3                        0
#                                         8                        0
#                             2           2                        0
#                                         5                        0
#                             3           3                        0

# %%
#drop NAs from POS
TOKENS = TOKENS.dropna(subset=['POS'])

# %%
DOCS = TOKENS[~TOKENS.POS.str.match(r'^(NN|VB)S?$')]\
    .groupby(BAG)\
    .term_str.apply(lambda  x:  x.tolist())\
    .reset_index()['term_str'].tolist()
DOCS = [doc for doc in DOCS if len(doc) > 1] # Lose single word docs

# %%
DOCS
# Out:
# [['right', 'real', 'quick', 'lucas', 'start', 'five'],
#  ['well',
#   'black',
#   'like',
#   'saw',
#   'thought',
#   'interrupting',
#   'like',
#   '30',
#   'like',
#   'well',
#   'hopefully',
#   'said',
#   'hopefully',
#   'sees',
#   'raising',
#   'yes',
#   'saw',
#   'got',
#   'went'],
#  ['oh',
#   'suppose',
#   'second',
#   'able',
#   'really',
#   'sure',
#   'shifting',
#   'going',
#   'next',
#   'makes',
#   'gave',
#   'asked',
#   'want',
#   'like',
#   'one',
#   'sure',
#   'thinking',
#   'like',
#   'critical',
#   'next',
#   'smoothly'],
#  ['thought',
#   'totally',
#   'fine',
#   'like',
#   'asked',
#   'one',
#   'thought',
#   'nicely',
#   'think',
#   'went',
#   'next',
#   'like',
#   'well',
#   'know',
#   'got',
#   'thinks',
#   'us',
#   'two',
#   'actually',
#   'thought',
#   'really',
#   'great'],
#  ['one', 'think', 'identified', 'need', 'correct', 'might', 'right'],
#  ['oh',
#   'lisa',
#   'really',
#   'one',
#   'said',
#   'well',
#   'clear',
#   'also',
#   'stated',
#   'one',
#   'cannot',
#   'exact',
#   'one',
#   'covered',
#   'could',
#   'blown'],
#  ['paragraph', 'four'],
#  ['one', 'far', 'incorrect', 'much', 'even', 'listening'],
#  ['like',
#   'especially',
#   'like',
#   'beginning',
#   'like',
#   'hard',
#   'sometimes',
#   'feel',
#   'like',
#   'like',
#   'wrong',
#   'want',
#   'like',
#   'especially',
#   'text',
#   'going',
#   'back',
#   'know',
#   'ava',
#   'says',
#   'new',
#   'says',
#   'first',
#   'ask',
#   'like',
#   'well',
#   'says',
#   'first',
#   'could',
#   'instead',
#   'like',
#   'well',
#   'um',
#   'keep',
#   'reading',
#   'later',
#   'get',
#   'might',
#   'says',
#   'like',
#   'know',
#   'could',
#   'two',
#   'could',
#   'either',
#   'back',
#   'find',
#   'like',
#   'oh',
#   'says',
#   'going',
#   'blown',
#   'maybe',
#   'go',
#   'back',
#   'also',
#   'might',
#   'like',
#   'oh',
#   'talking',
#   'anywhere',
#   'could',
#   'read',
#   'four',
#   'read',
#   'paragraph',
#   'four',
#   'like',
#   'oh',
#   'says',
#   'like',
#   'want',
#   'first',
#   'back',
#   'find',
#   'able',
#   'well',
#   'four',
#   'well',
#   'might',
#   'nervous',
#   'first',
#   'little',
#   'right'],
#  ['sure',
#   'another',
#   'first',
#   'answered',
#   'incorrectly',
#   'remember',
#   'said',
#   'nervous',
#   'oh',
#   'get',
#   'nervous',
#   'maybe',
#   'answered',
#   'happy',
#   'remember'],
#  ['say',
#   'excited',
#   'also',
#   'another',
#   'give',
#   'text',
#   'like',
#   'one',
#   'would',
#   'cool',
#   'would',
#   'also',
#   'redirect',
#   'like',
#   'true',
#   'one',
#   'really',
#   'great',
#   'asking',
#   'lisa',
#   'feels',
#   'pismo',
#   'brings',
#   'lie',
#   'know',
#   'pismo',
#   'brings',
#   'know',
#   'one',
#   'would',
#   'like',
#   'oh',
#   'know'],
#  ['know',
#   'might',
#   'able',
#   'like',
#   'oh',
#   '20',
#   'says',
#   'say',
#   'like',
#   'could',
#   'like',
#   'well',
#   'check',
#   'paragraph',
#   '14',
#   '20',
#   'one',
#   'clammy',
#   'like'],
#  ['really',
#   'either',
#   'direct',
#   'back',
#   'getting',
#   'wrong',
#   'exactly',
#   'confused',
#   'right',
#   'saying',
#   'four',
#   '20',
#   'might'],
#  ['alright',
#   'next',
#   'still',
#   'want',
#   'sure',
#   'good',
#   'going',
#   'trying',
#   'asking',
#   'using'],
#  ['umm', 'pretty', 'good'],
#  ['liked',
#   'lisa',
#   'said',
#   'jasmine',
#   'said',
#   'lisa',
#   'feeling',
#   'nervous',
#   'told',
#   'feeling',
#   'nervous',
#   'makes',
#   'textual',
#   'right',
#   'want',
#   'really',
#   'continue',
#   'even',
#   'ethan',
#   'ethan',
#   'said',
#   'thought',
#   'lisa',
#   'feeling',
#   'excited',
#   'new',
#   'said',
#   'makes',
#   'say',
#   'right',
#   'great',
#   'probing',
#   'textual',
#   'sure',
#   'hey',
#   'want',
#   'want',
#   'give',
#   'us',
#   'wrong',
#   'get',
#   'us',
#   'wrong',
#   'give',
#   'wrong'],
#  ['um',
#   'think',
#   'well',
#   'first',
#   'like',
#   'asking',
#   'might',
#   'getting',
#   'like',
#   'completely',
#   'misunderstanding',
#   'like',
#   'drawing',
#   'whole',
#   'fully',
#   'understand',
#   'going',
#   'back',
#   'like',
#   'well',
#   'let',
#   'us',
#   'maybe',
#   'think',
#   'kind',
#   'like',
#   'like',
#   'maybe',
#   'like',
#   'far',
#   'going',
#   'back',
#   'like',
#   'us',
#   'back',
#   'says',
#   'instead'],
#  ['one',
#   'want',
#   'want',
#   'want',
#   'would',
#   'bring',
#   'really',
#   'good',
#   'want',
#   'put',
#   'disregard',
#   'last',
#   'many',
#   'like',
#   'alright',
#   'let',
#   'us',
#   'alright',
#   'summary',
#   'going',
#   'ethan',
#   'tells',
#   'thought',
#   "lisa's",
#   'excited',
#   'new',
#   'know',
#   'incorrect',
#   'first',
#   'going',
#   'going',
#   'sharing',
#   'using',
#   'think',
#   'like',
#   'connecting',
#   'specific',
#   'using',
#   'think',
#   'important',
#   'using',
#   'know',
#   'probably',
#   'going',
#   'incorrect',
#   'incorrect',
#   'least',
#   'know',
#   'coming',
#   'somewhere',
#   'know',
#   'know',
#   'coming',
#   'going',
#   'saying',
#   'might',
#   'us',
#   'different',
#   'one',
#   'came',
#   'wrong',
#   'going',
#   'back',
#   'additional',
#   'textual',
#   'textual',
#   'give',
#   'still',
#   'struggles',
#   'read',
#   'four',
#   'lisa',
#   'getting',
#   'another',
#   'guiding',
#   'want',
#   'alright',
#   'us',
#   'going',
#   'going',
#   'lisa',
#   'likely',
#   'lisa',
#   'likely',
#   'pismo',
#   'brings',
#   'going'],
#  ['lisa', 'likely', 'pismo', 'brings', 'lie'],
#  ['lisa', 'calm'],
#  ['um', 'thank', 'sharing', 'using', 'think'],
#  ['um', 'paragraph', '22', 'says', 'smiled', 'relaxed'],
#  ['um', 'might', 'us', 'different'],
#  ['oh',
#   'well',
#   'earlier',
#   'text',
#   'paragraph',
#   '20',
#   'says',
#   'pounding',
#   'loudly',
#   'maybe',
#   'feeling',
#   'maybe',
#   'scared',
#   'nervous',
#   'great',
#   'practicing',
#   'going',
#   'scenario',
#   'two'],
#  ['um',
#   'good',
#   'um',
#   'feel',
#   'like',
#   'always',
#   'surprised',
#   'smoothly',
#   'actually',
#   'goes',
#   'like',
#   'know',
#   'like',
#   'supposed',
#   'guess',
#   'um',
#   'mean',
#   'thought',
#   'thought',
#   'went',
#   'well',
#   'seem',
#   'really',
#   'pretty',
#   'easily',
#   'lisa',
#   'excited'],
#  ['thought',
#   'like',
#   'super',
#   'confident',
#   'really',
#   'like',
#   'like',
#   'feeling',
#   'nervous',
#   'like',
#   'probing',
#   'textual',
#   'want',
#   'like',
#   'probing',
#   'textual',
#   'really',
#   'good',
#   'providing',
#   'consistent'],
#  ['tempting', 'tempting'],
#  ['much',
#   'faster',
#   'want',
#   'probing',
#   'supporting',
#   'sorry',
#   'scaffolding',
#   'making',
#   'basically',
#   'get',
#   'wrong'],
#  ['um',
#   'think',
#   'first',
#   'always',
#   'think',
#   'half',
#   'oh',
#   'nevermind',
#   'think',
#   'differently',
#   'think',
#   'important',
#   'thinking',
#   'thinking',
#   'exactly',
#   'want',
#   'also',
#   'think',
#   'could',
#   'said',
#   'like',
#   'simple',
#   'like',
#   'raising',
#   'trying',
#   'making',
#   'best',
#   'think',
#   'sometimes',
#   'need',
#   'explicitly',
#   'know',
#   'like',
#   'else',
#   'knew',
#   'except'],
#  ['want', 'going', 'going', 'would', 'make', 'going'],
#  ['would', 'great'],
#  ['ethan',
#   'tells',
#   'thought',
#   'lisa',
#   'feeling',
#   'excited',
#   'new',
#   'knew',
#   'incorrect',
#   'going',
#   'first',
#   'going',
#   'sharing',
#   'ethan',
#   'using',
#   'asked',
#   'using',
#   'think',
#   'really',
#   'good',
#   'ethan',
#   'initial',
#   'excited',
#   'might',
#   'wrong',
#   'even',
#   'gives',
#   'wrong',
#   'going',
#   'thank',
#   'ethan',
#   'might',
#   'us',
#   'different',
#   'going',
#   'back',
#   'second',
#   'back',
#   'second',
#   'like',
#   'alright',
#   'first',
#   'wrong',
#   'looking',
#   'going',
#   'back',
#   'second',
#   'additional',
#   'reading',
#   'inaudible',
#   'sent',
#   'back',
#   'additional',
#   'textual',
#   'cannot',
#   'additional',
#   'going',
#   'paragraph',
#   'four',
#   'lisa',
#   'sending',
#   'back',
#   'giving',
#   'finding',
#   'textual',
#   'normal',
#   'struggle'],
#  ['might', 'better'],
#  ['um',
#   'mean',
#   'think',
#   'like',
#   'said',
#   'encouraged',
#   'first',
#   'unsure',
#   '0r',
#   'getting',
#   'wrong',
#   'always',
#   'get',
#   'raise',
#   'one',
#   'mean',
#   'might',
#   'second',
#   'needs',
#   'individual',
#   'giving',
#   'individualized',
#   'also',
#   'important'],
#  ['absolutely',
#   'us',
#   'going',
#   'going',
#   'going',
#   'lisa',
#   'likely',
#   'pismo',
#   'brings'],
#  ['lisa', 'likely', 'pismo', 'brings', 'lie'],
#  ['think', 'lisa', 'calm'],
#  ['sharing', 'good', 'think'],
#  ['well', '22', 'says', 'smiled', 'relaxed'],
#  ['true', 'good', 'might', 'us', 'different', "lisa's", 'though'],
#  ['oh',
#   'well',
#   '20',
#   'says',
#   'pounding',
#   'loudly',
#   'maybe',
#   'nervous',
#   'scared'],
#  ['maybe', 'nervous', 'scared', 'look', 'four', 'supports'],
#  ['says',
#   'great',
#   'great',
#   'following',
#   'additional',
#   'ready',
#   'think',
#   'think',
#   'ready',
#   'next',
#   'ready',
#   'second'],
#  ['hey', 'teacher'],
#  ['think', 'went', 'better', 'first'],
#  ['think',
#   'able',
#   'able',
#   'little',
#   'think',
#   'able',
#   'maybe',
#   'little',
#   'specific',
#   'like',
#   'know',
#   'even',
#   'got',
#   'slightly',
#   'wrong',
#   'correct',
#   'also',
#   'like',
#   'little'],
#  ['thought',
#   'really',
#   'good',
#   'scaffold',
#   'first',
#   'pull',
#   'textual',
#   'jasmine',
#   'said',
#   'feeling',
#   'nervous',
#   'asked',
#   'pushed',
#   'textual',
#   'ethan',
#   'ethan',
#   'got',
#   'wrong',
#   'said',
#   'thought',
#   'lisa',
#   'feeling',
#   'excited',
#   'new',
#   'said',
#   'made',
#   'think',
#   'probing',
#   'textual',
#   'really',
#   'good',
#   'get',
#   'textual',
#   'answer',
#   'wrong',
#   'textual',
#   'really',
#   'want',
#   'visual',
#   'going',
#   'going',
#   'give',
#   'wrong',
#   'going',
#   'going',
#   'going',
#   'put',
#   'going',
#   'want',
#   'actually',
#   'well',
#   'wrong',
#   'ethan',
#   'says',
#   'thought',
#   'lisa',
#   'feeling',
#   'excited',
#   'new',
#   'know',
#   'incorrect',
#   'going',
#   'going',
#   'sharing',
#   'ethan',
#   'using',
#   'think',
#   'good',
#   'know',
#   "ethan's",
#   'probably',
#   'going',
#   'wrong',
#   'textual',
#   'probably',
#   'going',
#   'aligned',
#   'original',
#   'know',
#   'wrong',
#   'still',
#   'showing',
#   'thinking',
#   'textual',
#   'going',
#   'asking',
#   'second',
#   'might',
#   'us',
#   'different',
#   'got',
#   'needs',
#   'back',
#   'additional',
#   'textual',
#   'important',
#   'gives',
#   'looking',
#   'textual',
#   'much',
#   'ethan',
#   'still',
#   'struggles',
#   'additional',
#   'textual',
#   'going',
#   'another',
#   'going',
#   'read',
#   'four',
#   'lisa',
#   'ethan',
#   'hard',
#   'finding',
#   'textual',
#   'going',
#   'textual',
#   'might',
#   'better'],
#  ['like',
#   'back',
#   'even',
#   'though',
#   'like',
#   'using',
#   'higher',
#   'thinking',
#   'know',
#   'still',
#   'still',
#   'want',
#   'able',
#   'right',
#   'needs',
#   'pointing',
#   'might',
#   'might',
#   'another',
#   'like',
#   'know',
#   'wrong',
#   'like',
#   'subtle',
#   'like',
#   'well',
#   'wrong',
#   'like',
#   'like',
#   'well',
#   'wrong',
#   'right',
#   'final',
#   'like',
#   'well',
#   'like',
#   'us',
#   'together',
#   'us',
#   'else',
#   'need'],
#  ['absolutely',
#   'us',
#   'together',
#   'going',
#   'going',
#   'lisa',
#   'likely',
#   'pizmo',
#   'brings',
#   'going',
#   'ahead'],
#  ['lisa', 'likely', 'pismo', 'brings', 'lie'],
#  ['think', 'lisa', 'calm'],
#  ['hear', 'using'],
#  ['well', '22', 'says', 'smiled', 'laughed'],
#  ['smiled', 'laughed', 'could', 'definitely', 'might', 'us', 'different'],
#  ['well',
#   'earlier',
#   '20',
#   'says',
#   'pounding',
#   'loudly',
#   'maybe',
#   'maybe',
#   'means',
#   'scared',
#   'nervous'],
#  ['scared',
#   'nervous',
#   'also',
#   'might',
#   'nervous',
#   'four',
#   'might',
#   'four',
#   'learned'],
#  ['perfect',
#   'great',
#   'know',
#   'like',
#   'going',
#   'going',
#   'going',
#   'might',
#   'able',
#   'additional',
#   'paragraphs',
#   'four',
#   'another',
#   'another',
#   'going',
#   'going',
#   'back',
#   'going',
#   'second',
#   'get',
#   'started'],
#  ['oh', 'teacher'],
#  ['um',
#   'good',
#   'little',
#   'think',
#   'last',
#   'managing',
#   'behavior',
#   'felt',
#   'little',
#   'comfortable',
#   'one'],
#  ['good',
#   'definitely',
#   'think',
#   'really',
#   'strong',
#   'especially',
#   'helping',
#   'every',
#   'said',
#   'correct',
#   'know',
#   'asked',
#   'another',
#   'redirected',
#   'specifically',
#   'ethan',
#   'said',
#   'know',
#   'might',
#   'feeling',
#   'excited',
#   'asking',
#   'able',
#   'back',
#   'savannah',
#   'savannah',
#   'whoever',
#   'said',
#   'new',
#   'intern',
#   'ava',
#   'ava',
#   'know',
#   'says',
#   'new',
#   'say',
#   'know',
#   'asking',
#   'us',
#   'really',
#   'might',
#   'like',
#   'oh',
#   'thought',
#   'said',
#   'well',
#   'us',
#   'look',
#   'might',
#   'really',
#   'great',
#   'scaffolding',
#   'think',
#   'even',
#   'also',
#   'correct',
#   'really',
#   'good',
#   'providing',
#   'practicing',
#   'like',
#   'like',
#   'looked',
#   'like',
#   'found',
#   'think',
#   'question',
#   'clear',
#   'jasmine',
#   'says',
#   "lisa's",
#   'feeling',
#   'nervous',
#   'asked',
#   'appropriate',
#   'referred',
#   'said',
#   'pounding',
#   'responded',
#   'starts',
#   'really',
#   'fast',
#   'might',
#   'uneasy',
#   'excited',
#   'could',
#   'asking',
#   'jasmine',
#   'us',
#   'like',
#   'continuing',
#   'like',
#   'continuing',
#   'thinking',
#   'well',
#   'ask',
#   'exactly',
#   'like',
#   'like',
#   'know',
#   'able',
#   'makes',
#   'feel',
#   'nervous',
#   'like',
#   'told',
#   'know',
#   'giving',
#   'descriptive',
#   'rather',
#   'giving',
#   'descriptive',
#   'well'],
#  ['like',
#   'savannah',
#   'gives',
#   'thinks',
#   'like',
#   'know',
#   'secretive',
#   'could',
#   'maybe',
#   'savannah',
#   'even',
#   'kind',
#   'clear'],
#  ['um',
#   'maybe',
#   'along',
#   'know',
#   'know',
#   'maybe',
#   'specific',
#   'like',
#   'might',
#   'much',
#   'lisa',
#   'many',
#   'secretive'],
#  ['continuing',
#   'text',
#   'particular',
#   'give',
#   'think',
#   'think',
#   'might',
#   'little',
#   'could',
#   'especially',
#   'know',
#   'feeling',
#   'nervous',
#   'pounding',
#   'probing',
#   'well',
#   'pounding',
#   'like',
#   'might',
#   'clammy',
#   'clammy',
#   'like',
#   'get',
#   'clammy',
#   'ever',
#   'happened',
#   'make',
#   'know',
#   'feeling',
#   'nervous',
#   'spot',
#   'following',
#   'since',
#   'gave',
#   'continue',
#   '20',
#   'giving',
#   'made',
#   'clear',
#   'noticing',
#   'adding'],
#  ['sometimes',
#   'little',
#   'sometimes',
#   'always',
#   'know',
#   'want',
#   'descriptive',
#   'pointing',
#   'also',
#   'want',
#   'sure',
#   'making',
#   'right',
#   'well',
#   'ready',
#   'round',
#   'two',
#   'ahead'],
#  ['think', 'went', 'felt', 'pretty', 'good'],
#  ['one',
#   'really',
#   'wanted',
#   'right',
#   'jasmine',
#   'said',
#   'gave',
#   'said',
#   'lisa',
#   'feeling',
#   'nervous',
#   'said',
#   'feeling',
#   'nervous',
#   'told',
#   'still',
#   'thought',
#   'great',
#   'really',
#   'probing',
#   'textual',
#   'visual',
#   'also',
#   'ethan',
#   'got',
#   'wrong',
#   'really',
#   'good',
#   'making',
#   'sure',
#   'probing',
#   'textual',
#   'even',
#   'get',
#   'wrong',
#   'looking',
#   'textual',
#   'want',
#   'give',
#   'us',
#   'give',
#   'us',
#   'going',
#   'going',
#   'going',
#   'along',
#   'model',
#   'let',
#   'us',
#   'ethan',
#   'gives',
#   'thought',
#   'lisa',
#   'feeling',
#   'excited',
#   'new',
#   'know',
#   'incorrect',
#   'going',
#   'sharing',
#   'ethan',
#   'using',
#   'think',
#   'already',
#   'keep',
#   'next',
#   'going',
#   'might',
#   'us',
#   'different',
#   'asking',
#   'one',
#   'ethan',
#   'probably',
#   'gave',
#   'aligned',
#   'need',
#   'wrong',
#   'also',
#   'aligned',
#   'long',
#   'aligned',
#   'know',
#   "ethan's",
#   'practicing',
#   'using',
#   'textual',
#   'marks',
#   'got',
#   'wrong',
#   'need',
#   'back',
#   'gives',
#   'back',
#   'finding',
#   'textual',
#   'needs',
#   'additional',
#   'would',
#   'read',
#   'four',
#   'lisa',
#   'would',
#   'might',
#   'better'],
#  ['think',
#   'encourages',
#   'said',
#   'also',
#   'dumb',
#   'whatever',
#   'getting',
#   'saying',
#   'sharing',
#   'showing',
#   'appreciate',
#   'tried',
#   'giving',
#   'helping'],
#  ['absolutely',
#   'still',
#   'trying',
#   'like',
#   'opening',
#   'making',
#   'like',
#   'like',
#   'going',
#   'supposed',
#   'us',
#   'us',
#   'going',
#   'going',
#   'lisa',
#   'likely',
#   'pizmo',
#   'brings'],
#  ['ready', 'well', 'lisa', 'likely', 'pismo', 'brings', 'lie'],
#  ['think', 'lisa', 'calm'],
#  ['sharing', 'makes', 'think'],
#  ['well', '22', 'says', 'smiled', 'relaxed'],
#  ['see', 'think', 'associate', 'smiling', 'calm', 'might', 'us', 'different'],
#  ['well', '20', 'says', 'pounding', 'loudly', 'maybe', 'scared', 'nervous'],
#  ['exactly',
#   'right',
#   'pounding',
#   'really',
#   'loud',
#   'fast',
#   'really',
#   'means',
#   'nervous',
#   'scared',
#   'good',
#   'using',
#   'might',
#   'feeling',
#   'great',
#   'going',
#   'back'],
#  ['thank',
#   'great',
#   'following',
#   'staying',
#   'connected',
#   'focusing',
#   'going',
#   'next',
#   'get',
#   'started'],
#  ['alright', 'went'],
#  ['think',
#   'right',
#   'little',
#   'sometimes',
#   'hard',
#   'sometimes',
#   'like',
#   'like',
#   'us',
#   'like',
#   'ethan'],
#  ['um',
#   'would',
#   'exactly',
#   'think',
#   'going',
#   'like',
#   'little',
#   'confusing',
#   'think',
#   'good',
#   'identifying',
#   'like',
#   'wrong',
#   'needed',
#   'oh',
#   'wrong',
#   'got',
#   'right',
#   'really',
#   'good',
#   'identifying',
#   'like',
#   'right',
#   'asking',
#   'follow',
#   'pointing',
#   'directly',
#   'think',
#   'upon',
#   'instead',
#   'telling',
#   'exactly',
#   'putting',
#   'little'],
#  ['sure', 'like'],
#  ['ethan',
#   'ethan',
#   'ethan',
#   'said',
#   'thought',
#   'lisa',
#   'feeling',
#   'excited',
#   'new',
#   'asked',
#   'like',
#   'made',
#   'think',
#   'ethan',
#   'responded',
#   'know',
#   'two',
#   'said',
#   'said',
#   'said',
#   'agreed',
#   'said',
#   'exciting',
#   'four',
#   'directly',
#   'pointed',
#   'rather',
#   'directly',
#   'pointing',
#   'could',
#   'actually',
#   'back',
#   'saying',
#   'well',
#   'asking',
#   'us',
#   'lisa',
#   'pismo',
#   'brings',
#   'asks',
#   'would',
#   'little',
#   'digging',
#   'say',
#   'like',
#   'oh',
#   'pounding',
#   'might',
#   'clammy',
#   'could',
#   'even',
#   'another',
#   'would',
#   'like',
#   'well',
#   'might',
#   'clammy',
#   'giving',
#   'little',
#   'within',
#   'rather',
#   'pointing'],
#  ['great', 'great'],
#  ['think',
#   'like',
#   'pointing',
#   'like',
#   'sometimes',
#   'like',
#   'aspiring',
#   'like',
#   'well',
#   'want',
#   'next',
#   'next',
#   'ava',
#   'new',
#   'um',
#   'saying',
#   'four',
#   'might',
#   'able',
#   'ava',
#   'right',
#   'without',
#   'giving',
#   'exact'],
#  ['think',
#   'like',
#   'similar',
#   'talking',
#   'saying',
#   'like',
#   'new',
#   'intern',
#   'looking',
#   'really',
#   'says'],
#  ['could',
#   'even',
#   'know',
#   'well',
#   'know',
#   'makes',
#   'us',
#   'know',
#   'saying',
#   'says',
#   'actually',
#   'really',
#   'good',
#   'saying',
#   'sometimes',
#   'reading',
#   'instead',
#   'know',
#   'could',
#   'say',
#   'reading',
#   'shows',
#   'probably',
#   'would',
#   'across'],
#  ['sure', 'great'],
#  ['little', 'lisa', 'feeling', 'think', 'feeling', 'relaxed', 'might'],
#  ['um',
#   'think',
#   'would',
#   'like',
#   'previously',
#   'like',
#   'makes',
#   'asked',
#   'lisa',
#   'likely',
#   'pismo',
#   'brings'],
#  ['say', 'feeling', 'relaxed'],
#  ['oh', 'would', 'would', 'like', 'would', 'like', 'well'],
#  ['22', 'says', 'smiled', 'relaxed', 'means', 'relaxed'],
#  ['would',
#   'well',
#   'lisa',
#   'likely',
#   'prismo',
#   'brings',
#   'lie',
#   'brings',
#   'lie',
#   'lie',
#   'detector'],
#  ['would',
#   'like',
#   'oh',
#   'brought',
#   'could',
#   'dig',
#   'um',
#   'great',
#   'want',
#   'thumbs',
#   'recognizing',
#   'correctly',
#   'trying',
#   'right',
#   'want',
#   'little',
#   'next',
#   'feeling',
#   'good'],
#  ['disappear', 'beat'],
#  ['um',
#   'good',
#   'usually',
#   'practiced',
#   'far',
#   'like',
#   'behavioral',
#   'like',
#   'nice',
#   'wanted'],
#  ['oh',
#   'thought',
#   'great',
#   'much',
#   'great',
#   'one',
#   'pushing',
#   'textual',
#   'great',
#   'got',
#   'right',
#   'pushed',
#   'textual',
#   'got',
#   'wrong',
#   'pushed',
#   'textual',
#   'great',
#   'also',
#   'ava',
#   'got',
#   'new',
#   'said',
#   'tells',
#   'us',
#   'new',
#   'really',
#   'great',
#   'really',
#   'great',
#   'said',
#   'pushed',
#   'ava',
#   'next',
#   'moved',
#   'think',
#   'ava',
#   'could',
#   'answered',
#   'could',
#   'pushed',
#   'textual'],
#  ['going',
#   'going',
#   'talking',
#   'going',
#   'another',
#   'like',
#   'give',
#   'us',
#   'wrong',
#   'misunderstand'],
#  ['um',
#   'think',
#   'asking',
#   'know',
#   'however',
#   'appropriate',
#   'think',
#   'like',
#   'got',
#   'helpful',
#   'rethinking',
#   'another',
#   'might',
#   'tried',
#   'specific',
#   'like',
#   'let',
#   'us',
#   'little',
#   'like',
#   'said',
#   'completely'],
#  ['think',
#   'great',
#   'great',
#   'like',
#   'going',
#   'going',
#   'going',
#   'goes',
#   'ethan',
#   'says',
#   'thought',
#   'lisa',
#   'feeling',
#   'excited',
#   'new',
#   'thought',
#   'lisa',
#   'feeling',
#   'excited',
#   'new',
#   'would',
#   'like',
#   'said',
#   'thank',
#   'sharing',
#   'using',
#   'think',
#   'first',
#   'like',
#   'right',
#   'ask',
#   'textual',
#   'right',
#   'lisa',
#   'textual',
#   'aligned',
#   'talking',
#   'right',
#   'still',
#   'found',
#   'going',
#   'second',
#   'say',
#   'might',
#   'us',
#   'different',
#   'first',
#   'need',
#   'looking',
#   'continue',
#   'would',
#   'said',
#   'read',
#   'paragraph',
#   'four',
#   'lisa',
#   'guiding',
#   'specifically',
#   'might',
#   'better'],
#  ['um',
#   'still',
#   'like',
#   'keeps',
#   'like',
#   'high',
#   'gives',
#   'still',
#   'still',
#   'get',
#   'right',
#   'also',
#   'going',
#   'like',
#   'successful',
#   'would',
#   'think',
#   'going',
#   'think',
#   'probably',
#   'happens',
#   'commonly',
#   'like',
#   'oh',
#   'getting',
#   'like',
#   'maybe',
#   'hearing',
#   'us',
#   'actually',
#   'answering',
#   'also',
#   'like',
#   'accountable',
#   'continuing'],
#  ['important',
#   'want',
#   'creating',
#   'making',
#   'normalized',
#   'going',
#   'giving',
#   'us',
#   'going',
#   'going',
#   'lisa',
#   'likely',
#   'prismo',
#   'brings',
#   'going'],
#  ['ok', 'htow', 'lisa', 'likely', 'pismo', 'brings'],
#  ['think', 'lisa', 'calm'],
#  ['makes', 'think', 'lisa', 'calm', 'made', 'think'],
#  ['well', '22', 'says', 'smiled'],
#  ['oh',
#   '22',
#   'said',
#   'smiled',
#   'relaxed',
#   'um',
#   'let',
#   'us',
#   'back',
#   'little',
#   'section',
#   '20',
#   'right',
#   'right',
#   'breaks'],
#  ['oh',
#   'mean',
#   '8',
#   'says',
#   'pounding',
#   'loudly',
#   'maybe',
#   'scared',
#   'nervous'],
#  ['right',
#   'asked',
#   'right',
#   'feeling',
#   'scared',
#   'nervous',
#   'um',
#   'right',
#   'oh',
#   'go',
#   'ahead',
#   'sorry',
#   'interrupted',
#   'great',
#   'great',
#   'wanted',
#   'actively',
#   'find',
#   'guiding',
#   'guiding',
#   'really',
#   'providing',
#   'think',
#   'maybe',
#   'going',
#   'going',
#   'start',
#   'going'],
#  ['perfect', 'go'],
#  ['alright', 'ready', 'yes', 'starting', 'one'],
#  ['hey', 'teacher'],
#  ['um', 'think', 'went', 'um'],
#  ['something',
#   'saw',
#   'want',
#   'really',
#   'want',
#   'sure',
#   'continue',
#   'pushing',
#   'textual',
#   'really',
#   'good',
#   'right',
#   'like',
#   'give',
#   'wrong',
#   'also',
#   'asking',
#   'textual',
#   'want',
#   'give',
#   'us',
#   'making',
#   'misunderstand'],
#  ['back',
#   'might',
#   'prompt',
#   'like',
#   'us',
#   'little',
#   'see',
#   'like',
#   'make',
#   'know',
#   'maybe',
#   'lisa',
#   'excited',
#   'pismo',
#   'brought',
#   'um',
#   'let',
#   'us',
#   'back',
#   'felt',
#   'like'],
#  ['looking',
#   'back',
#   'great',
#   'going',
#   'actually',
#   'back',
#   'looking',
#   'back',
#   'finding',
#   'textual',
#   'real',
#   'need',
#   'going',
#   'would',
#   'going',
#   'first'],
#  ['ok',
#   'ethan',
#   'says',
#   'thought',
#   'lisa',
#   'feeling',
#   'excited',
#   'new',
#   'know',
#   'incorrect',
#   'going',
#   'sharing',
#   'using',
#   'think',
#   'already',
#   'pushing',
#   'next',
#   'going',
#   'probably',
#   'going',
#   'aligns',
#   'want',
#   'know',
#   'wrong',
#   'gives',
#   'wrong',
#   'going',
#   'second',
#   'back',
#   'textual',
#   'saying',
#   'might',
#   'us',
#   'different',
#   'going',
#   'quite',
#   'correct',
#   'need',
#   'back',
#   'ethan',
#   'struggles',
#   'going',
#   'third',
#   'read',
#   'paragraph',
#   'four',
#   '22',
#   'lisa',
#   'first',
#   'textual',
#   'thinking',
#   'second',
#   'push',
#   'back',
#   'looking',
#   'textual',
#   'third',
#   'giving',
#   'textual',
#   'like'],
#  ['might', 'better'],
#  ['um',
#   'think',
#   'still',
#   'like',
#   'making',
#   'like',
#   'rather',
#   'saying',
#   'oh',
#   'back',
#   'feels',
#   'like',
#   'less',
#   'like',
#   'wrong',
#   'like',
#   'oh',
#   'looking',
#   'different'],
#  ['absolutely',
#   'us',
#   'going',
#   'going',
#   'lisa',
#   'likely',
#   'prismo',
#   'brings',
#   'ahead',
#   'ready'],
#  ['lisa', 'likely', 'pismo', 'brings', 'lie'],
#  ['think', 'lisa', 'calm'],
#  ['thank', 'sharing', 'using', 'think'],
#  ['well', '22', 'says', 'smiled', 'relaxed', 'think', 'calm', 'happy'],
#  ['us', 'back', 'four', 'us', 'lisa'],
#  ['oh', 'four', 'us', 'nervous', 'say', 'back', 'want'],
#  ['oh', 'might', 'us', 'different'],
#  ['us',
#   'asking',
#   'might',
#   'us',
#   'different',
#   'oh',
#   '20',
#   'says',
#   'pounding',
#   'loudly',
#   'maybe',
#   'feeling',
#   'scared',
#   'nervous'],
#  ['good', 'read', 'four', 'us', 'lisa'],
#  ['great', 'ready', 'would', 'like', 'really', 'next'],
#  ['next',
#   'going',
#   'second',
#   'second',
#   'going',
#   'make',
#   'giving',
#   'back',
#   'textual',
#   'second'],
#  ['ready', 'second'],
#  ['um',
#   'felt',
#   'like',
#   'think',
#   'halfway',
#   'like',
#   'oh',
#   'really',
#   'like',
#   'providing',
#   'feedback',
#   'like',
#   'thought',
#   'like',
#   'leading',
#   'think',
#   'could',
#   'provided',
#   'better',
#   'tried',
#   'great'],
#  ['well',
#   'really',
#   'interesting',
#   'say',
#   'something',
#   'thought',
#   'really',
#   'well',
#   'really',
#   'want',
#   'like'],
#  ['really', 'crowed', 'jasmine', 'textual'],
#  ['going', 'real', 'second'],
#  ['jasmine',
#   'said',
#   'lisa',
#   'feeling',
#   'nervous',
#   'said',
#   'nervous',
#   'great',
#   'tells',
#   'nervous',
#   'really',
#   'key',
#   'made',
#   'like',
#   'like',
#   'puts',
#   'like',
#   'able',
#   'textual',
#   'gets',
#   'need',
#   'want',
#   'give',
#   'wrong'],
#  ['going',
#   'two',
#   'going',
#   'well',
#   'get',
#   'using',
#   'textual',
#   'going',
#   'textual'],
#  ['initially', 'correctly'],
#  ['well',
#   'think',
#   'said',
#   'like',
#   'think',
#   'getting',
#   'like',
#   'know',
#   'one',
#   'like',
#   'like',
#   'going',
#   'back',
#   'found',
#   'like',
#   'like',
#   'said',
#   'really',
#   'correct',
#   'us',
#   'us',
#   'right',
#   'like',
#   'took',
#   'wrong',
#   'think',
#   'like',
#   'said',
#   'probing',
#   'came',
#   'incorrect',
#   'like',
#   'affirming',
#   'like',
#   'nervous',
#   'laughing',
#   'right',
#   'us'],
#  ['yes',
#   'exactly',
#   'going',
#   'going',
#   'going',
#   'going',
#   'loud',
#   'ethan',
#   'tells',
#   'thought',
#   'lisa',
#   'feeling',
#   'excited',
#   'new',
#   'first',
#   'going',
#   'thank',
#   'sharing',
#   'ethan',
#   'using',
#   'think',
#   'pushing',
#   'back',
#   'immediately',
#   'ethan',
#   'likely',
#   'going',
#   'wrong',
#   'going',
#   'supports',
#   'know',
#   'wrong',
#   'know',
#   'building',
#   'critical',
#   'making',
#   'fine',
#   'want',
#   'critical',
#   'want',
#   'back',
#   'say',
#   'might',
#   'us',
#   'different',
#   'us',
#   'know',
#   'needs',
#   'adjusting',
#   'needs',
#   'additional',
#   'might',
#   'might',
#   'want',
#   'many'],
#  ['ethan',
#   'still',
#   'struggles',
#   'finding',
#   'going',
#   'going',
#   'four',
#   'lisa',
#   'give',
#   'give',
#   'second',
#   'guide',
#   'textual',
#   'want'],
#  ['ask', 'ask', 'scaffolding', 'provi', 'sending', 'oh', 'sorry', 'ask'],
#  ['yes', 'yes', 'absolutely', 'us'],
#  ['going', 'going'],
#  ['going', 'lisa', 'likely', 'pismo', 'brings'],
#  ['lisa', 'likely', 'pizmo', 'brings'],
#  ['think', 'lisa', 'calm'],
#  ['really', 'well', 'sharing', 'tells', 'calm'],
#  ['well', '22', 'says', 'smiled', 'relaxed'],
#  ['like', 'cited', 'might', 'us', 'different', 'originally', 'found'],
#  ['20', 'says', 'pounding', 'loudly', 'maybe', 'scared', 'nervous'],
#  ['alright', 'like', 'go', 'ahead', 'four', 'learn', 'lisa'],
#  ['great',
#   'noticed',
#   'follow',
#   'even',
#   'gave',
#   'right',
#   'still',
#   'like',
#   'ready',
#   'additional',
#   'additonal',
#   'thought'],
#  ['doubles', 'like'],
#  ['like', 'whether', 'like', 'going', 'whole'],
#  ['going', 'get', 'started'],
#  ['um',
#   'think',
#   'one',
#   'like',
#   'agreeing',
#   'like',
#   'like',
#   'honestly',
#   'great',
#   'really',
#   'um',
#   'entertain',
#   'like',
#   'really'],
#  ['like', 'especially'],
#  ['alright', 'ready'],
#  ['felt',
#   'pretty',
#   'solid',
#   'often',
#   'feel',
#   'like',
#   'like',
#   'many',
#   'sure',
#   'could',
#   'like',
#   'saying',
#   'like',
#   'saying',
#   'felt',
#   'like'],
#  ['something',
#   'thought',
#   'really',
#   'good',
#   'thought',
#   'really',
#   'good',
#   'want',
#   'first',
#   'start',
#   'like',
#   'got',
#   'ask',
#   'feeling',
#   'nervous',
#   'feeling',
#   'got',
#   'like',
#   'ethan',
#   'lisa',
#   'feeling',
#   'excited',
#   'new',
#   'still',
#   'use',
#   'textual',
#   'good',
#   'pushing',
#   'textual',
#   'something',
#   'thought',
#   'good',
#   'going',
#   'working',
#   'scaffolding',
#   'like',
#   'give',
#   'incorrect'],
#  ['correct', 'one'],
#  ['noticed',
#   'good',
#   'going',
#   'first',
#   'textual',
#   'guided',
#   'textual',
#   'really',
#   'good',
#   'going',
#   'going',
#   'additional',
#   'going',
#   'additional',
#   'guiding',
#   'textual'],
#  ['going', 'would', 'gave', 'struggling', 'correct', 'going', 'along'],
#  ['ethan',
#   'says',
#   'thought',
#   'lisa',
#   'feeling',
#   'excited',
#   'first',
#   'exactly',
#   'want',
#   'sharing',
#   'textual',
#   'said',
#   'thank',
#   'sharing',
#   'using',
#   'using',
#   'think',
#   'next',
#   'going',
#   'going',
#   'like',
#   'assuming',
#   'going',
#   'wrong',
#   'textual',
#   'make',
#   'wrong',
#   'textual',
#   'might',
#   'aligned',
#   'want',
#   'probably',
#   'going',
#   'alligned',
#   'different',
#   'going',
#   'might',
#   'us',
#   'different',
#   'going',
#   'might',
#   'us',
#   'different',
#   'finding',
#   'textual',
#   'important',
#   'going',
#   'second',
#   'still',
#   'struggling',
#   'going',
#   'going',
#   'read',
#   'four',
#   'lisa',
#   'read',
#   'paragraph',
#   '22',
#   'lisa'],
#  ['kay',
#   'basically',
#   'gave',
#   'gave',
#   'like',
#   'top',
#   'bottom',
#   'adding',
#   'middle',
#   'adding'],
#  ['alright', 'let', 'us', 'better'],
#  ['might', 'better'],
#  ['oh', 'gives', 'without', 'like', 'giving', 'easily', 'another', 'bad'],
#  ['yes',
#   'allows',
#   'productively',
#   'giving',
#   'absolutely',
#   'going',
#   'going',
#   'going',
#   'going',
#   'lisa',
#   'likely',
#   'pizmo',
#   'brings'],
#  ['lisa', 'likely', 'pizmo', 'brings', 'lie'],
#  ['think', 'lisa', 'calm'],
#  ['think', 'calm', 'using', 'think', 'lisa', 'calm'],
#  ['well', '22', 'says', 'smiled', 'relaxed'],
#  ['good', 'good', 'using', 'might', 'us', 'different'],
#  ['oh',
#   'well',
#   'look',
#   'right',
#   '20',
#   'says',
#   'pounding',
#   'loudly',
#   'maybe',
#   'feeling',
#   'different',
#   'maybe',
#   'scared',
#   'nervous'],
#  ['excellent', 'excellent', 'finding', 'using', 'original', 'awesome'],
#  ['great', 'would', 'going', 'going', 'practicing', 'second'],
#  ['sounds', 'good', 'right'],
#  ['going', 'give', 'wrong'],
#  ['alright', 'ready'],
#  ['last', 'often', 'get', 'went'],
#  ['pretty', 'well', 'think', 'clarified', 'pretty', 'well'],
#  ['would',
#   'definitely',
#   'think',
#   'addressed',
#   'able',
#   'right',
#   'ethan',
#   'says',
#   "lisa's",
#   'excited',
#   'said',
#   'know',
#   'right',
#   'shore',
#   'well',
#   'paragraph',
#   '13',
#   'pointed',
#   'right',
#   'instead',
#   'pointing',
#   'want',
#   'little',
#   'want',
#   'want',
#   'call',
#   'right',
#   'started',
#   'started',
#   'asking',
#   'want',
#   'sure',
#   'giving',
#   'um',
#   "ethan's",
#   'ethan',
#   'says',
#   'excited',
#   'two',
#   'pointed',
#   'talked',
#   'asking',
#   'could',
#   '13',
#   'know',
#   'well',
#   'asking',
#   'ethan',
#   '13',
#   'pretty',
#   'much',
#   '13',
#   'always',
#   '20',
#   '22',
#   '20',
#   '14',
#   'would',
#   'like',
#   'know',
#   'us',
#   'nervous',
#   'would',
#   'going',
#   'tell',
#   'exactly',
#   'um',
#   'really',
#   'nice',
#   'ethan',
#   'pointed',
#   'like',
#   'oh',
#   'lied',
#   'nice',
#   'could',
#   'say',
#   'like',
#   'think',
#   'could',
#   'ava',
#   'without',
#   'telling',
#   'four'],
#  ['mmm', 'could'],
#  ['could',
#   'like',
#   'know',
#   'well',
#   'know',
#   'took',
#   'lie',
#   'nervous',
#   'tells',
#   'us',
#   'know',
#   'tells',
#   'us',
#   'might',
#   'like',
#   'might',
#   'say',
#   'like',
#   'oh',
#   'lied',
#   'paragraph',
#   'four',
#   'says',
#   'might',
#   'blown',
#   'might',
#   'blown',
#   'know',
#   'right',
#   'um',
#   'say',
#   'might',
#   'would',
#   'spy',
#   'like',
#   'um',
#   'really',
#   'noted',
#   'like',
#   'long',
#   'like',
#   'excited',
#   'many',
#   'get',
#   'think',
#   'spy',
#   'like',
#   'really',
#   'good',
#   'making',
#   'understanding',
#   'clear',
#   'saying',
#   'know',
#   'oh',
#   'like',
#   'us',
#   'thought',
#   'real',
#   'could',
#   'saying',
#   'know',
#   'makes',
#   'think',
#   'spy',
#   'like',
#   'know',
#   'leads',
#   'might',
#   'know',
#   'asking',
#   'sure',
#   'clear',
#   'sure',
#   'um',
#   'one',
#   'asking',
#   'lisa',
#   'might',
#   'feeling',
#   'say',
#   'think',
#   'calm',
#   '22',
#   'says',
#   'relaxed'],
#  ['um', 'lisa', 'felt', 'anywhere', 'felt', 'like', 'else'],
#  ['oh', 'earlier', 'feeling', 'nervous', 'sweaty', 'clammy'],
#  ['would',
#   'could',
#   'like',
#   'well',
#   'earlier',
#   'talking',
#   'feeling',
#   'could',
#   'even',
#   'says',
#   'relaxed',
#   'could',
#   'well',
#   'relaxed',
#   'pismo',
#   'tells',
#   'back',
#   'next',
#   'pointed',
#   'next',
#   'want',
#   'like',
#   'really',
#   'good',
#   'already',
#   'want',
#   'telling',
#   'instead',
#   'give',
#   'pretty',
#   'already'],
#  ['wait', 'right'],
#  ['yes', 'right'],
#  ['going',
#   'literally',
#   'would',
#   'different',
#   'like',
#   'literally',
#   'exact',
#   'wiped'],
#  ['pretty', 'good', 'guess'],
#  ['thought',
#   'thought',
#   'pretty',
#   'really',
#   'well',
#   'probing',
#   'textual',
#   'lisa',
#   'jasmine',
#   'said',
#   'lisa',
#   'feeling',
#   'nervous',
#   'said',
#   'feeling',
#   'nervous',
#   'ethan',
#   'said',
#   'thought',
#   'lisa',
#   'feeling',
#   'excited',
#   'new',
#   'said',
#   'think',
#   'want',
#   'give',
#   'wrong',
#   'going',
#   'going',
#   'going',
#   'would',
#   'give',
#   'wrong',
#   'going',
#   'dropping',
#   'along',
#   'ethan',
#   'tells',
#   'thought',
#   'lisa',
#   'feeling',
#   'excited',
#   'new',
#   'know',
#   'incorrect',
#   'going',
#   'thank',
#   'sharing',
#   'ethan',
#   'using',
#   'think',
#   'great',
#   'know',
#   'probably',
#   'going',
#   'wrong',
#   'though',
#   'gave',
#   'wrong',
#   'probably',
#   'going',
#   'also',
#   'wrong',
#   'want',
#   'going',
#   'second',
#   'back',
#   'going',
#   'tell',
#   'us',
#   'different',
#   'might',
#   'us',
#   'different',
#   'cues',
#   'wrong',
#   'thathe',
#   'back'],
#  ['looking',
#   'textual',
#   "scaffold's",
#   'enough',
#   'needs',
#   'additional',
#   'four',
#   'lisa',
#   'actually',
#   'ethan',
#   'told',
#   'feeling',
#   'excited',
#   'thought',
#   'lisa',
#   'feeling',
#   'excited',
#   'good',
#   'missing',
#   'giving',
#   'back'],
#  ['might', 'better'],
#  ['gives',
#   'using',
#   'allows',
#   'like',
#   'fixing',
#   'told',
#   'like',
#   'oh',
#   'look',
#   'kind'],
#  ['yes',
#   'absolutely',
#   'going',
#   'going',
#   'going',
#   'going',
#   'lisa',
#   'likely',
#   'pizmo',
#   'brings',
#   'going',
#   'go',
#   'ahead',
#   'ready'],
#  ['lisa', 'likely', 'pizmo', 'brings', 'lie'],
#  ['think', 'lisa', 'calm'],
#  ['well', '22', 'says', 'smiled', 'relaxed'],
#  ['else', 'might', 'us', 'different', 'feeling'],
#  ['oh',
#   'well',
#   '20',
#   'read',
#   'says',
#   'pounding',
#   'loudly',
#   'maybe',
#   'scared',
#   'nervous'],
#  ['different', 'lisa', 'based', 'good'],
#  ['alright', 'great', 'going', 'great', 'great', 'going'],
#  ['going', 'begin'],
#  ['think', 'went', 'well', 'got', 'feel', 'prepared', 'first'],
#  ['thought',
#   'like',
#   'warm',
#   'calm',
#   'created',
#   'felt',
#   'like',
#   'wanted',
#   'like',
#   'want',
#   'saw',
#   'wanted',
#   'well',
#   'jasmine',
#   'said',
#   'lisa',
#   'feeling',
#   'nervous',
#   'correct',
#   'said',
#   'makes',
#   'think',
#   'might',
#   'feeling',
#   'nervous',
#   'textual',
#   'thinking',
#   'visual',
#   'got',
#   'wrong',
#   'immediately',
#   'gave',
#   'gave',
#   'told',
#   'going',
#   'going',
#   'like'],
#  ['giving', 'us', 'enough'],
#  ['might', 'comes'],
#  ['yes',
#   'alone',
#   'might',
#   'us',
#   'coming',
#   'get',
#   'wrong',
#   'might',
#   'get',
#   'right',
#   'might',
#   'fully',
#   'us',
#   'thinking',
#   'going',
#   'going',
#   'would',
#   'get',
#   'right',
#   'get',
#   'wrong',
#   'probing',
#   'text',
#   'even',
#   'right',
#   'wrong',
#   'going',
#   'dropping',
#   'jasmine',
#   'says',
#   'lisa',
#   'feeling',
#   'nervous',
#   'correct',
#   'still',
#   'want',
#   'sure',
#   'want',
#   'visual',
#   'going',
#   'going',
#   'thank',
#   'using',
#   'textual',
#   'know',
#   'using',
#   'textual',
#   'know',
#   'us',
#   'wrong',
#   'ethan',
#   'saying',
#   'thought',
#   'lisa',
#   'feeling',
#   'excited',
#   'new',
#   'would',
#   'still',
#   'thank',
#   'sharing',
#   'ethan',
#   'using',
#   'textual',
#   'know',
#   'think',
#   'might',
#   'better'],
#  ['probably',
#   'better',
#   'would',
#   'whether',
#   'vocabulary',
#   'related',
#   'would',
#   'clearer',
#   'made',
#   'say'],
#  ['exactly',
#   'us',
#   'going',
#   'going',
#   'lisa',
#   'likely',
#   'pizmo',
#   'brings',
#   'going'],
#  ['lisa', 'likely', 'pizmo', 'brings'],
#  ['think', 'lisa', 'nervous'],
#  ['text', 'came'],
#  ['well', 'four', 'says', 'would', 'four', 'says', 'feeling', 'nervous'],
#  ['yes', 'great', 'using'],
#  ['whether',
#   'get',
#   'wrong',
#   'correct',
#   'great',
#   'following',
#   'great',
#   'asking',
#   'excited',
#   'going',
#   'next',
#   'think',
#   'ready',
#   'next'],
#  ['say',
#   'incorrect',
#   'thank',
#   'came',
#   'would',
#   'right',
#   'asking',
#   'could',
#   'seem',
#   'like',
#   'lisa',
#   'happy',
#   'would',
#   'correct',
#   'ultimately'],
#  ['want',
#   'allowing',
#   'productively',
#   'heavy',
#   'telling',
#   'correct',
#   'never',
#   'get',
#   'hard',
#   'go',
#   'textual',
#   'correct',
#   'incorrect',
#   'want',
#   'shared',
#   'shared',
#   'thought',
#   'come'],
#  ['yes', 'thought', 'productively'],
#  ['alright', 'great', 'let', 'us', 'second', 'additional', 'get', 'started'],
#  ['ready', 'started', 'going', 'next'],
#  ['perfect', 'ready'],
#  ['went', 'teacher'],
#  ['um',
#   'well',
#   'first',
#   'think',
#   'got',
#   'little',
#   'tripped',
#   'first',
#   'started',
#   'wrong',
#   'straight',
#   'second',
#   'got',
#   'wrong',
#   'focused',
#   'talking',
#   'think',
#   'next',
#   'probably',
#   'really',
#   'confusing',
#   'messed',
#   'think'],
#  ['would',
#   'think',
#   'good',
#   'generating',
#   'asking',
#   'text',
#   'said',
#   'wrong',
#   'like',
#   'know',
#   'know',
#   'let',
#   'us',
#   'us',
#   'clarify',
#   'challenging',
#   'sometimes',
#   'know',
#   'might',
#   'like',
#   'want',
#   'important',
#   'think',
#   'might',
#   'little',
#   'hard',
#   'question',
#   'two',
#   'like',
#   'first',
#   'ethan',
#   'even',
#   'though',
#   'pointed',
#   'wrong',
#   'still',
#   'might',
#   'nervous',
#   'rather',
#   'want',
#   'get',
#   'back',
#   'call',
#   'rather',
#   'know',
#   'say',
#   'um',
#   'know',
#   'keep',
#   'reading',
#   '22',
#   'helps',
#   'us',
#   'rather',
#   'directly',
#   'want',
#   'lead',
#   'ethan',
#   'says',
#   'know',
#   'really',
#   'excited',
#   'says',
#   'right',
#   'appropriate',
#   'know',
#   'might',
#   'feeling',
#   'get',
#   'know',
#   'first',
#   'asking',
#   "lisa's",
#   'brought',
#   'us',
#   'specific',
#   'asking',
#   'rather',
#   'like',
#   'reading',
#   'actual'],
#  ['know',
#   'might',
#   'like',
#   'oh',
#   'like',
#   'know',
#   'need',
#   'read',
#   'like',
#   'oh',
#   'might',
#   'lying',
#   'nervous',
#   'clammy'],
#  ['go', 'ahead'],
#  ['oh', 'interrupting'],
#  ['oh', 'go', 'ahead'],
#  ['say',
#   'like',
#   'say',
#   'like',
#   'know',
#   'like',
#   'saying',
#   'feeling',
#   'asking',
#   'pizmo',
#   'brings',
#   'hopefully',
#   'going',
#   'still',
#   'able'],
#  ['guess',
#   'know',
#   'good',
#   'sometimes',
#   'going',
#   'able',
#   'pretty',
#   'quick',
#   'might',
#   'able',
#   'looking',
#   'like',
#   'oh',
#   'pull',
#   'wrong',
#   'long',
#   'could',
#   'like',
#   'look',
#   'starting',
#   'think',
#   '14',
#   '20'],
#  ['say',
#   'like',
#   'read',
#   'like',
#   'like',
#   'still',
#   'think',
#   'excited',
#   'like',
#   'ask',
#   'rather',
#   'like',
#   'must',
#   'nervous'],
#  ['went', 'gave', 'feel', 'like'],
#  ['exactly',
#   'exactly',
#   'want',
#   'want',
#   'really',
#   'valid',
#   'ava',
#   'new',
#   'intern',
#   'could',
#   'questioning'],
#  ['wait', 'ava', 'ava', 'sorry', 'ava', 'asks', 'ava', 'says', 'new', 'oh'],
#  ['done', 'couple'],
#  ['sorry', 'really', 'paying'],
#  ['ask',
#   'lisa',
#   'really',
#   'ava',
#   'says',
#   'new',
#   'intern',
#   'might',
#   'oh',
#   'see',
#   'like',
#   'know',
#   'well',
#   'would',
#   'probably',
#   'said',
#   'makes',
#   'think',
#   'said',
#   'first'],
#  ['said', 'well', 'reading', 'think', 'appropriate'],
#  ['think',
#   'said',
#   'keep',
#   'looking',
#   'four',
#   'like',
#   'second',
#   'say',
#   'well',
#   'keep',
#   'reading',
#   'might',
#   'later',
#   'tells',
#   'us',
#   'differently'],
#  ['um',
#   'especially',
#   'us',
#   'one',
#   'sure',
#   'like',
#   'know',
#   'else',
#   'coming',
#   'know',
#   'going',
#   'tells',
#   'us',
#   'makes',
#   'us',
#   'might'],
#  ['ava', 'little', 'still', 'stumped', 'like', 'read', 'us', 'four'],
#  ['think',
#   'brought',
#   'good',
#   'forgot',
#   'think',
#   'based',
#   'looking',
#   'think',
#   'five'],
#  ['terrible', 'setting'],
#  ['thank', 'guess', 'working', 'rather', 'telling'],
#  ['um',
#   'really',
#   'well',
#   'excited',
#   'well',
#   'actually',
#   'get',
#   'going',
#   'little',
#   'different',
#   'well',
#   'going',
#   'telling',
#   'great',
#   'started',
#   'said',
#   'jasmine',
#   'gave',
#   'correct',
#   'actually',
#   'asked',
#   'potential',
#   'know',
#   'maybe',
#   'using',
#   'probed',
#   'textual',
#   'ethan',
#   'gave',
#   'wrong',
#   'probed',
#   'told',
#   'textual',
#   'ava',
#   'ava',
#   'consistently',
#   'probing',
#   'textual',
#   'great',
#   'second',
#   'really',
#   'well',
#   'ava',
#   'struggling',
#   'like',
#   'astudent',
#   'intern',
#   'probed',
#   'said',
#   'read',
#   'tells',
#   'us',
#   'maybe',
#   'new',
#   'like',
#   'really',
#   'high',
#   'gives',
#   'back',
#   'additional',
#   'could',
#   'additional',
#   'told',
#   'dev',
#   'four',
#   'like',
#   'provided',
#   'many',
#   'many',
#   'ava',
#   'really',
#   'great',
#   'want',
#   'giving',
#   'descriptive',
#   'give',
#   'really',
#   'great'],
#  ['going', 'name', 'good', 'saw'],
#  ['um',
#   'one',
#   'gave',
#   'like',
#   'really',
#   'thorough',
#   'used',
#   'like',
#   'multiple',
#   'yes'],
#  ['think',
#   'savannah',
#   'said',
#   'great',
#   'going',
#   'going',
#   'going',
#   'descriptive',
#   'good',
#   'great',
#   'able',
#   'great',
#   'well',
#   'savannah',
#   'says',
#   'lisa',
#   'kept',
#   'talking',
#   'secretive',
#   'would',
#   'even',
#   'says',
#   'four',
#   'great'],
#  ['would',
#   'great',
#   'savannah',
#   'love',
#   'stated',
#   'said',
#   'told',
#   'thought',
#   'lisa',
#   'stating',
#   'provided',
#   'textual',
#   'came',
#   'key',
#   'stated',
#   'provided',
#   'textual',
#   'repeating',
#   'providing',
#   'descriptive',
#   'one',
#   'knows',
#   'well',
#   'able',
#   'well',
#   'might',
#   'better'],
#  ['well',
#   'probably',
#   'much',
#   'productive',
#   'gives',
#   'specifically',
#   'also',
#   'like',
#   'like',
#   'saying',
#   'like',
#   'really',
#   'like',
#   'substantial'],
#  ['absolutely',
#   'going',
#   'going',
#   'going',
#   'lisa',
#   'lisa',
#   'makes',
#   'makes',
#   'going',
#   'going',
#   'descriptive',
#   'lisa',
#   'really',
#   'makes',
#   'think'],
#  ['lisa', 'really', 'makes', 'think'],
#  ['think', 'lisa', 'four', 'says', 'would', 'covered'],
#  ['wow',
#   'great',
#   'really',
#   'liked',
#   'stated',
#   'thought',
#   'really',
#   'good',
#   'gave',
#   'textual'],
#  ['awesome',
#   'awesome',
#   'stating',
#   'great',
#   'referencing',
#   'textual',
#   'going',
#   'going',
#   'practicing',
#   'um',
#   'start'],
#  ['full', 'one'],
#  ['yes', 'full', 'one'],
#  ['think', 'went', 'well'],
#  ['really',
#   'wanted',
#   'really',
#   'well',
#   'got',
#   'got',
#   'wrong',
#   'always',
#   'made',
#   'sure',
#   'tells',
#   'made',
#   'feel',
#   'super',
#   'great',
#   'consistent',
#   'really',
#   'good',
#   'even',
#   'gave',
#   'correct',
#   'think',
#   'jessica',
#   'asked',
#   'made',
#   'like',
#   'nervous',
#   'thought',
#   'really',
#   'great',
#   'clever',
#   'like',
#   'thought',
#   'really',
#   'interesting',
#   'well',
#   'wanted',
#   'wanted',
#   'figuring',
#   'give',
#   'us',
#   'give',
#   'us',
#   'going',
#   'going',
#   'going',
#   'would',
#   'going',
#   'first',
#   'along'],
#  ['ethen',
#   'tells',
#   'thought',
#   'lisa',
#   'feeling',
#   'excited',
#   'new',
#   'knew',
#   'incorrect',
#   'going',
#   'ethan',
#   'allowing',
#   'ethan',
#   'sharing',
#   'using',
#   'think',
#   'ethan',
#   'probably',
#   'going',
#   'wrong',
#   'least',
#   'know',
#   'able',
#   'based',
#   'really',
#   'good',
#   'going',
#   'might',
#   'us',
#   'different',
#   'back',
#   'needs',
#   'back',
#   'additional',
#   'think',
#   'saw',
#   'really',
#   'strong',
#   'really',
#   'big',
#   'want',
#   'textual',
#   'second',
#   'really',
#   'really',
#   'strong',
#   'still',
#   'struggles',
#   'second',
#   'read',
#   'four',
#   'lisa',
#   'might',
#   'better',
#   'might',
#   'better'],
#  ['mean',
#   'scaffolded',
#   'think',
#   'like',
#   'got',
#   'wrong',
#   'trying',
#   'different',
#   'might',
#   'right',
#   'like',
#   'giving',
#   'maybe',
#   'seeing',
#   'like',
#   'oh',
#   'well',
#   'maybe',
#   'missed',
#   'point',
#   'find',
#   'another',
#   'scaffolded',
#   'individual'],
#  ['absolutely',
#   'great',
#   'like',
#   'realizing',
#   'like',
#   'connecting',
#   'back',
#   'um',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'lisa',
#   'likely',
#   'pismo',
#   'brings',
#   'going'],
#  ['lisa', 'likely', 'prismo', 'brings', 'lie'],
#  ['think', 'lisa', 'calm'],
#  ['well', 'sharing', 'using', 'makes', 'think', 'calm'],
#  ['oh', 'well', '22', 'says', 'smiled', 'relaxed'],
#  ['might', 'us', 'different', 'feeling'],
#  ['oh',
#   'well',
#   '20',
#   'says',
#   'like',
#   'says',
#   'pounding',
#   'loudly',
#   'maybe',
#   'scared',
#   'nervous'],
#  ['right',
#   'sometimes',
#   'beats',
#   'loudly',
#   'feel',
#   'nervous',
#   'maybe',
#   'feeling',
#   'nervous',
#   'paragraph',
#   '20',
#   'us'],
#  ['great',
#   'following',
#   'continuing',
#   'like',
#   'directly',
#   'going',
#   'second',
#   'get',
#   'get',
#   'started'],
#  ['maybe', 'made', 'maybe'],
#  ['um', 'feel', 'like', 'every', 'back', 'thought', 'knew', 'guess'],
#  ['absolutely',
#   'definitely',
#   'would',
#   'think',
#   'refer',
#   'back',
#   'really',
#   'important',
#   'want',
#   'found',
#   'good',
#   'potentially',
#   'using',
#   'like',
#   'also',
#   'able',
#   'back',
#   'like',
#   'connect',
#   'really',
#   'good',
#   'asked',
#   'consistantly',
#   'found',
#   'oh',
#   'bad',
#   'um',
#   'think',
#   'work',
#   'um',
#   'like',
#   'guide',
#   'rather',
#   'would',
#   'want',
#   'supports',
#   'uncovering',
#   'couple',
#   'able'],
#  ['trying', 'said'],
#  ['definitely',
#   'noticed',
#   'able',
#   'first',
#   'asked',
#   'first',
#   'lisa',
#   'pismo',
#   'brings',
#   'um',
#   'first',
#   'says',
#   'know',
#   'nervous',
#   'ask',
#   'verify',
#   'appropriate',
#   'next',
#   'ethan',
#   'says',
#   'excited',
#   'ask',
#   'say',
#   'possible',
#   'want',
#   'sure',
#   'possible',
#   'quite',
#   'looking',
#   'want',
#   'know',
#   'back',
#   'asking',
#   'lisa',
#   'feels',
#   'big',
#   'new',
#   'york',
#   'city',
#   'company',
#   'asked',
#   'feels',
#   'pismo',
#   'brings',
#   'even',
#   'restating',
#   'prompted',
#   'different',
#   'different',
#   'saying',
#   'like',
#   'oh',
#   'possible',
#   'maybe',
#   'shifting',
#   'well',
#   'might',
#   'excited',
#   'working',
#   'want',
#   'lisa',
#   'feels',
#   'brought',
#   'thinking',
#   'like',
#   'generally',
#   'cool',
#   'exact',
#   'um',
#   'second',
#   'intern',
#   'think',
#   'little',
#   'better',
#   'better',
#   'saying',
#   'like',
#   'well',
#   'know',
#   'gave',
#   'away',
#   'almost',
#   'saying',
#   'lisa',
#   'know',
#   'tells',
#   'us',
#   'loses',
#   'tells',
#   'us',
#   'might',
#   'blown',
#   'rather',
#   'want',
#   'understand'],
#  ['makes', 'wondering', 'want', 'trying', 'right', 'exactly', 'sure', 'see'],
#  ['done',
#   'um',
#   'could',
#   'could',
#   'two',
#   'different',
#   'telling',
#   'four',
#   'sometimes',
#   'might',
#   'necessary',
#   'could',
#   'saying',
#   'know',
#   'us',
#   'one',
#   'someplace',
#   'else',
#   'tells',
#   'might',
#   'guiding',
#   'little',
#   'could',
#   'like',
#   'read',
#   'four',
#   'first',
#   'starting',
#   'little',
#   'broader'],
#  ['um',
#   'um',
#   'think',
#   'back',
#   'one',
#   'lisa',
#   'feeling',
#   'raise',
#   'say',
#   'think',
#   'calm',
#   'might'],
#  ['would',
#   'well',
#   'even',
#   'tried',
#   'might',
#   'rooted',
#   'textual',
#   'would',
#   'like',
#   'know'],
#  ['would', '22', 'says', 'lisa', 'feeling', 'relaxed'],
#  ['22', 'um', 'would', 'well', 'find', 'safe', 'presents', 'lie'],
#  ['would',
#   'look',
#   'like',
#   'oh',
#   'clammy',
#   'lied',
#   'oops',
#   'um',
#   'feeling',
#   'certain',
#   'great',
#   'know',
#   'looking',
#   'um',
#   'second',
#   'five',
#   'fast',
#   'going',
#   'prompting',
#   'rather',
#   'necessarily',
#   'giving',
#   'good'],
#  ['righty', 'sorry', 'went', 'teacher'],
#  ['um', 'pretty', 'well', 'think'],
#  ['would',
#   'would',
#   'think',
#   'really',
#   'great',
#   'making',
#   'like',
#   'asking',
#   'making',
#   'sure',
#   'able',
#   'like',
#   'text',
#   'really',
#   'important',
#   'give',
#   'text',
#   'like',
#   'foundational',
#   'want',
#   'also',
#   'want',
#   'sure',
#   'able',
#   'um',
#   'similar',
#   'also',
#   'really',
#   'good',
#   'answer',
#   'incorrectly',
#   'like',
#   'incorrect',
#   'explained',
#   'incorrect',
#   'like',
#   'good',
#   'maybe',
#   'like',
#   'next',
#   'addressed',
#   'though',
#   'think',
#   'together',
#   'two',
#   'exactly',
#   'lisa',
#   'excited',
#   'know',
#   'said',
#   'like',
#   'see',
#   'keep',
#   'reading',
#   'look',
#   '20',
#   'like',
#   'exactly',
#   'incorrect',
#   'want',
#   'want',
#   'feedback',
#   'incorrect'],
#  ['want', 'like', 'oh', '20', 'say', 'like', 'back', 'bring'],
#  ['exactly',
#   'right',
#   'um',
#   'know',
#   'know',
#   'going',
#   'ethan',
#   'start',
#   'excited',
#   'know',
#   'ask',
#   'go',
#   'one',
#   'cool',
#   'think',
#   'even',
#   'started',
#   'strong',
#   'like',
#   'sure',
#   'like',
# ...
#   '22',
#   'says',
#   'lisa',
#   'smiled',
#   'relaxed',
#   'think',
#   'calm',
#   'like',
#   'couch'],
#  ['um', 'could', 'like', 'good', 'read', '20', 'feeling'],
#  ['running',
#   'good',
#   'want',
#   'sure',
#   'recognizes',
#   'know',
#   'might',
#   'want',
#   'elsewhere',
#   'asking',
#   'else',
#   'get',
#   'second',
#   'want',
#   'questioning',
#   'want',
#   'using',
#   'slightly',
#   'focused',
#   'around'],
#  ['sometimes',
#   'know',
#   'hard',
#   'especially',
#   'give',
#   'like',
#   'like',
#   'hard',
#   'like',
#   'wrong',
#   'like'],
#  ['natural',
#   'like',
#   'wrong',
#   'next',
#   'know',
#   'us',
#   'read',
#   'know',
#   'paragraph',
#   'talking',
#   'still',
#   'think',
#   'tell',
#   'like',
#   'going',
#   'seems',
#   'like',
#   'good',
#   'crossed'],
#  ['going', 'back', 'totally', 'setting', 'really', 'quickly', 'um', 'went'],
#  ['good',
#   'feel',
#   'like',
#   'would',
#   'trying',
#   'think',
#   'hard',
#   'like',
#   'read',
#   'familiar',
#   'like',
#   'printed',
#   'like',
#   'like',
#   'went',
#   'actual',
#   'like',
#   'one',
#   'hitting',
#   'definitely',
#   'took',
#   'longer',
#   'would',
#   'liked',
#   'actual',
#   'think',
#   'one',
#   'like',
#   'trying',
#   'like',
#   'little',
#   'would',
#   'like',
#   'wanted',
#   'little',
#   'like',
#   'definitely',
#   'felt',
#   'little',
#   'constrained'],
#  ['would',
#   'definitely',
#   'saying',
#   'like',
#   'got',
#   'maybe',
#   'would',
#   'liked',
#   'little',
#   'better',
#   'rather',
#   'pointing',
#   'first',
#   'noticed',
#   'wanted',
#   'one',
#   'like',
#   'us',
#   'looking',
#   'jasmine',
#   'raised',
#   'good',
#   'continuing',
#   'back',
#   'important',
#   'text',
#   'important'],
#  ['cannot',
#   'really',
#   'without',
#   'think',
#   'like',
#   'like',
#   'really',
#   'like',
#   'said',
#   'like',
#   'need',
#   'like',
#   'cannot',
#   'thin',
#   'really',
#   'using',
#   'given',
#   'us'],
#  ['right',
#   'using',
#   'connect',
#   'pointing',
#   'want',
#   'us',
#   'ethan',
#   'says',
#   'excited',
#   'responded',
#   'oh',
#   'excited',
#   'excite',
#   'excited',
#   'appropriate'],
#  ['struggling', 'like', 'never', 'like', 'turning', 'around'],
#  ['think',
#   'asking',
#   'text',
#   'saying',
#   'makes',
#   'think',
#   'know',
#   'makes',
#   'think',
#   'excited',
#   'know',
#   'might',
#   'new',
#   'york',
#   'city',
#   'talking',
#   'well',
#   'else',
#   'maybe',
#   'four',
#   '20',
#   'makes',
#   'think',
#   'differently',
#   'back',
#   'like',
#   'based',
#   'changed',
#   'maybe',
#   'would',
#   'maybe',
#   'excited',
#   'best',
#   'nervous',
#   'better',
#   'yes',
#   'think',
#   'another',
#   'another',
#   'ask',
#   'think',
#   "lisa's",
#   'feeling',
#   'say',
#   'think',
#   'calm',
#   'could'],
#  ['would',
#   'indicates',
#   'lisa',
#   'feeling',
#   'calm',
#   'specifically',
#   'regarding'],
#  ['great',
#   'like',
#   'right',
#   'calm',
#   'asked',
#   'would',
#   'well',
#   '22',
#   'says',
#   'relaxed',
#   'relaxed',
#   'calm'],
#  ['lisa', 'relaxed', 'lisa', 'feeling', 'relaxed'],
#  ['um', 'next', 'says', 'believes', 'falsified', 'lacks', 'done'],
#  ['might', 'made', 'lisa', 'feel', 'nervous', 'relaxed'],
#  ['last',
#   '30',
#   'continuing',
#   'helps',
#   'together',
#   'know',
#   'calm',
#   'might',
#   'feeling',
#   'nervous',
#   '22',
#   'might',
#   'like',
#   'based',
#   'read',
#   'feeling',
#   'nervous',
#   'continued',
#   'get',
#   'sometimes',
#   'know',
#   'said',
#   'felt',
#   'like',
#   'slow',
#   'sometimes',
#   'might',
#   'little',
#   'slow',
#   'still',
#   'giving',
#   'enter',
#   'second',
#   'want',
#   'answer',
#   'incorrectly',
#   'getting',
#   'incorrect',
#   'asking',
#   'shift',
#   'going'],
#  ['went',
#   'fine',
#   'think',
#   'last',
#   'little',
#   'like',
#   'real',
#   'would',
#   'never',
#   'worked',
#   'um',
#   'know',
#   'would',
#   'like',
#   'huh'],
#  ['definitely', 'wanted'],
#  ['think',
#   'one',
#   'really',
#   'engaging',
#   'went',
#   'back',
#   'quick',
#   'quick',
#   'shows',
#   'super',
#   'engaged',
#   'really',
#   'also',
#   'valued',
#   'like',
#   'interesting',
#   'going',
#   'like',
#   'asking',
#   'going',
#   'another',
#   'one',
#   'going',
#   'back',
#   'like',
#   'consistently',
#   'asked',
#   'super',
#   'important',
#   'working',
#   'want',
#   'text',
#   'one',
#   'think',
#   'want',
#   'noticed',
#   'like',
#   'back',
#   'sort',
#   'like',
#   'positioning',
#   'nervous',
#   'excited',
#   'exactly',
#   'sure',
#   'necessarily',
#   'always',
#   'clear',
#   'getting',
#   'want',
#   'sure',
#   'provide',
#   'ask',
#   'scaffolded',
#   'sorry',
#   'cannot'],
#  ['totally', 'fine'],
#  ['coach', 'gets', 'squeaky'],
#  ['broke', "dog's"],
#  ['back',
#   'right',
#   'want',
#   'scaffolded',
#   'right',
#   'helping',
#   'see',
#   'want',
#   'ethan',
#   'thinking',
#   'one',
#   'thing',
#   'exciting'],
#  ["jasmine's", 'thinking', 'actually', 'asking', 'us'],
#  ['right', 'specifically'],
#  ['right', 'like', 'two', 'great', 'two', 'great', 'great'],
#  ['see', 'see', 'right'],
#  ['still',
#   'know',
#   'like',
#   'ethan',
#   'like',
#   'provided',
#   'provided',
#   'supports',
#   'us',
#   'asking',
#   'us',
#   'us',
#   '20',
#   'clammy',
#   'pounding',
#   'like',
#   'redirecting',
#   'different',
#   'might',
#   'excited',
#   'best'],
#  ['know',
#   'sometimes',
#   'uncomfortable',
#   'know',
#   'right',
#   'also',
#   'want',
#   'best'],
#  ['think',
#   'back',
#   'would',
#   'got',
#   'two',
#   'er',
#   'two',
#   'two',
#   'different',
#   'might',
#   'getting',
#   'ethan',
#   'excited',
#   'best',
#   'maybe',
#   'nervous',
#   'better'],
#  ['mean',
#   'could',
#   'thinking',
#   'understanding',
#   'whole',
#   'asking',
#   'seen',
#   'whole',
#   'know',
#   "think's",
#   'going',
#   'next',
#   'right'],
#  ['bring', 'saying', 'like', 'well', 'know', 'happy', 'right'],
#  ['like',
#   'looking',
#   'like',
#   'ethan',
#   'told',
#   'us',
#   'first',
#   'one',
#   'thing',
#   'cool',
#   'maybe',
#   'happens',
#   'later',
#   'better',
#   'feeling',
#   'brought',
#   'like',
#   'thinking',
#   'rather',
#   'us',
#   'great',
#   'wrong',
#   'giving'],
#  ['two',
#   'like',
#   'ava',
#   'er',
#   'intern',
#   'brought',
#   'paragraph',
#   'four',
#   'like',
#   'oh',
#   'might',
#   'lying',
#   'maybe',
#   'help',
#   'ava',
#   'maybe',
#   'little',
#   'sooner',
#   'since',
#   'one',
#   'pretty',
#   'short'],
#  ['beyond',
#   'beyond',
#   'think',
#   'even',
#   'saying',
#   'focusing',
#   'right',
#   'focusing',
#   'key',
#   'centering',
#   'around',
#   'meets',
#   'right',
#   'right',
#   'away',
#   'er',
#   'four'],
#  ['right',
#   'instead',
#   'saying',
#   'know',
#   'like',
#   'like',
#   'interesting',
#   'us',
#   'ahead',
#   'four',
#   'like',
#   'tells',
#   'us',
#   'intern',
#   'us',
#   'later',
#   'think',
#   'really',
#   'great',
#   'leading',
#   'want',
#   'move',
#   'second',
#   'going',
#   'one',
#   'scaffold',
#   'using'],
#  ['awesome', 'well', 'thank', 'teacher', 'apologize'],
#  ['totally', 'fine'],
#  ['alright', 'went'],
#  ['think',
#   'went',
#   'think',
#   'sure',
#   'figured',
#   'easier',
#   'need',
#   'felt',
#   'better',
#   'started',
#   'referring',
#   'realized',
#   'could',
#   'um',
#   'think',
#   'ethan',
#   'could',
#   'maybe',
#   'explain',
#   'overall',
#   'felt'],
#  ['would',
#   'definitely',
#   'saw',
#   'started',
#   'referring',
#   'like',
#   'grew',
#   'richer',
#   'ultimately',
#   'text',
#   'want',
#   'us',
#   'definitely',
#   'think',
#   'good',
#   'started',
#   'would',
#   'definitely',
#   'like',
#   'praise',
#   'think',
#   'also',
#   'saying',
#   'ethan',
#   'also',
#   'think',
#   'responds',
#   'correct',
#   'like',
#   'going',
#   'think',
#   'really',
#   'great',
#   'engaged',
#   'like',
#   'continued',
#   'talking',
#   'say',
#   'like',
#   'yes',
#   'right',
#   'wrong',
#   'questioned',
#   'exactly',
#   'want',
#   'going',
#   'helps',
#   'questioning',
#   'ethan',
#   'trying',
#   'think'],
#  ['think',
#   'one',
#   'different',
#   'like',
#   'could',
#   'different',
#   'think',
#   'interpreting',
#   'like',
#   'guess',
#   'first',
#   'marble',
#   'exciting',
#   'really',
#   'considering',
#   'could',
#   'bad',
#   'considering',
#   'might',
#   'different',
#   'think',
#   'comes',
#   'maybe',
#   'higher',
#   'like'],
#  ['think',
#   'know',
#   'kept',
#   'pointing',
#   'like',
#   'cool',
#   'want',
#   'like',
#   'cool',
#   'might',
#   'excited',
#   'us',
#   "lisa's",
#   'brought',
#   'could',
#   'like',
#   'read',
#   '14',
#   'right',
#   'still',
#   'lisa',
#   'might',
#   'might',
#   "lisa's",
#   'smiled',
#   'thanked',
#   'speeding',
#   'growing',
#   'could',
#   'like',
#   'still',
#   'excited',
#   'may',
#   'feeling',
#   'else',
#   'know',
#   'ask',
#   'text',
#   'right',
#   'maybe',
#   '14',
#   'still',
#   'think',
#   'excited',
#   'maybe',
#   'new',
#   'text'],
#  ['want', 'sure', 'good', 'raised', 'say', 'think', "lisa's", 'might'],
#  ['think',
#   'would',
#   'probably',
#   'either',
#   'paragraph',
#   '14',
#   '14',
#   'later',
#   'one',
#   'lisa',
#   'clammy',
#   'speeds',
#   'like'],
#  ['exactly',
#   'right',
#   'would',
#   'would',
#   'maybe',
#   'like',
#   'text',
#   'makes',
#   'excited',
#   'makes',
#   'calm',
#   'sometimes',
#   'like',
#   '22',
#   'says',
#   'relaxed',
#   'could',
#   'hmm',
#   'like',
#   'might',
#   'else',
#   'shows',
#   'feeling',
#   'read',
#   '14',
#   'pointing',
#   'right',
#   'think',
#   'intern',
#   'say',
#   'intern',
#   'would'],
#  ['think',
#   'would',
#   'ever',
#   'like',
#   'guess',
#   'could',
#   'like',
#   'ever',
#   'indicate'],
#  ['would',
#   'good',
#   'first',
#   'want',
#   'first',
#   'text',
#   'made',
#   'think',
#   'would',
#   'like',
#   'well',
#   'literally',
#   'first',
#   'could',
#   'oh',
#   'else',
#   'maybe',
#   'makes',
#   'us',
#   'else',
#   'might',
#   'could',
#   'check',
#   '22',
#   'four',
#   'would',
#   'lied',
#   'timers',
#   'next',
#   'text',
#   'right'],
#  ['thank', 'participating', 'us', 'um', 'started', 'um', 'went'],
#  ['know', 'think', 'went', 'pretty', 'well', 'would', 'happy', 'back', 'like'],
#  ['also',
#   'like',
#   'definitely',
#   'impressed',
#   'questioned',
#   'asked',
#   'know',
#   'continued',
#   'scaffolded',
#   'really',
#   'appropriately',
#   'reading',
#   'like',
#   'well',
#   'actually',
#   'says',
#   'like',
#   'pointed',
#   'right',
#   'like',
#   'looking',
#   'need',
#   'ideal',
#   'going',
#   'one',
#   'little',
#   'coaching',
#   'think',
#   'actually',
#   'misinterpreted',
#   'one',
#   'little'],
#  ['oh', 'brings'],
#  ['like', 'would', 'paragraph', '19', '20'],
#  ['see', 'bad'],
#  ['looking', 'like'],
#  ['like',
#   'questioning',
#   'still',
#   'really',
#   'jasmine',
#   'looking',
#   'nervous',
#   'right',
#   'want',
#   'like',
#   'says',
#   'like',
#   'says',
#   'want'],
#  ['little',
#   'think',
#   'going',
#   'done',
#   'gotten',
#   'want',
#   'really',
#   'sure',
#   'give',
#   'like',
#   'containing',
#   'like',
#   'looking'],
#  ['obviously',
#   'looking',
#   'mean',
#   'making',
#   'whatever',
#   'want',
#   'like',
#   'like',
#   'lisa',
#   'might',
#   'really',
#   'long',
#   'back',
#   'like',
#   'reasonable'],
#  ['got', 'backed'],
#  ['want', 'want', 'third', 'looking', 'connects'],
#  ['like',
#   "lisa's",
#   'nervous',
#   'says',
#   '20',
#   'pounding',
#   'know',
#   'pounds',
#   'nervous',
#   'connecting',
#   'getting',
#   'together',
#   'questioning',
#   'questioning',
#   'appropriate',
#   'misunderstanding',
#   'asking',
#   'want',
#   'given',
#   'three',
#   'really'],
#  ['could',
#   'know',
#   'jasmine',
#   'say',
#   '20',
#   'says',
#   'pounding',
#   'know',
#   'nervous',
#   'could',
#   'like',
#   'also',
#   'known',
#   'else',
#   'like',
#   'looking'],
#  ['could',
#   'love',
#   'directly',
#   'answered',
#   'backed',
#   'text',
#   'explained',
#   'picked',
#   'goes',
#   'back',
#   'could',
#   'random',
#   'got',
#   'relates'],
#  ['actually',
#   'perfect',
#   'provide',
#   'like',
#   'else',
#   'expecting',
#   'else',
#   'looking',
#   'comes',
#   'providing',
#   'three',
#   'think',
#   'another',
#   'think',
#   'another',
#   'say',
#   'think',
#   'lisa',
#   'think',
#   'like',
#   'another',
#   'think',
#   'another',
#   'talked',
#   'like',
#   'billion',
#   'know',
#   'think',
#   'like',
#   'amazon',
#   'know',
#   'like',
#   'want',
#   'amazon',
#   'want',
#   'amazon',
#   'think',
#   'maybe',
#   'inspired',
#   'another',
#   'might'],
#  ['would',
#   'glad',
#   'think',
#   'think',
#   'keeping',
#   'said',
#   'looked',
#   'back',
#   'saw',
#   'one',
#   'billion',
#   'think',
#   'thinking',
#   'real',
#   'right',
#   'thinking',
#   'real',
#   'comparing',
#   'learning',
#   'real',
#   'thinking',
#   'know',
#   'amazon',
#   'real',
#   'want',
#   'amazon',
#   'connecting',
#   'know',
#   'real'],
#  ['providing',
#   'like',
#   'letting',
#   'know',
#   'thinking',
#   'together',
#   'makes',
#   'second',
#   'want',
#   'giving',
#   'high',
#   'else',
#   'first',
#   'make',
#   'sure',
#   'think',
#   '19',
#   '20',
#   'like',
#   'right',
#   'ready',
#   'ready'],
#  ['alright', 'ready'],
#  ['first',
#   'want',
#   'could',
#   'made',
#   'sound',
#   'super',
#   'nervous',
#   'like',
#   'would',
#   'guessed',
#   'said',
#   'good',
#   'good',
#   'one',
#   'noticed',
#   'really',
#   'well',
#   'really',
#   'made',
#   'sure',
#   'used',
#   'text',
#   'asked',
#   'thinking',
#   'said',
#   'like',
#   'well',
#   'referring',
#   'back',
#   'good',
#   'like',
#   'going',
#   'maybe',
#   'stumbled',
#   'maybe',
#   'sure'],
#  ['enough', 'like', 'think', 'especially', 'checking', 'different'],
#  ['really',
#   'really',
#   'challenging',
#   'think',
#   'first',
#   'goes',
#   'pacing',
#   'always',
#   'feel',
#   'like',
#   'think',
#   'one',
#   'felt',
#   'like',
#   'moved',
#   'appropriate',
#   'know',
#   'little',
#   'went',
#   'back',
#   'wanted',
#   'sure',
#   'understood',
#   'super',
#   'clear',
#   'first',
#   'know',
#   'asked',
#   'jasmine',
#   'thought',
#   'talked',
#   'ethan',
#   'spoke',
#   'made',
#   'sure',
#   'ethan',
#   'helped',
#   'really',
#   'strong',
#   'um',
#   'think',
#   'maybe',
#   'noticed',
#   'sure',
#   'maybe',
#   'two'],
#  ['like', 'ah', 'know', 'felt', 'like', 'oh', 'god'],
#  ['um', 'ava', 'might', 'made'],
#  ['think', 'already', 'forgot'],
#  ['says', 'new'],
#  ['really', 'could', 'mentions', 'could'],
#  ['um',
#   'noticed',
#   'like',
#   'knew',
#   'hoping',
#   'quite',
#   'yet',
#   'happens',
#   'sometimes',
#   'timed',
#   'necessarily',
#   'like',
#   'back',
#   'looking',
#   'four'],
#  ['paragraph',
#   'four',
#   'yes',
#   'oh',
#   'would',
#   'able',
#   'really',
#   'good',
#   'paragraph',
#   'four'],
#  ['um',
#   'remembered',
#   'paragraph',
#   'four',
#   'ava',
#   'say',
#   'well',
#   'says',
#   'one',
#   'intern',
#   'might',
#   'said',
#   'knowing',
#   'got',
#   'paragraph',
#   'four'],
#  ['might',
#   'redirected',
#   'four',
#   'maybe',
#   'says',
#   'would',
#   'basically',
#   'super'],
#  ['would', 'read', 'would', 'asked', 'ava'],
#  ['probably', 'would', 'asked', 'ava', 'found'],
#  ['would',
#   'appropriate',
#   'still',
#   'giving',
#   'thinking',
#   'typically',
#   'like',
#   'want',
#   'wanting',
#   'like',
#   'oh',
#   'says',
#   'intern',
#   'guess',
#   'exactly',
#   'right',
#   'scaffolding',
#   'giving',
#   'whether',
#   'reading',
#   'giving',
#   'still',
#   'giving'],
#  ['think', 'going', 'back', 'one', 'say', 'think', 'lisa', 'calm', 'would'],
#  ['would', 'text', 'feel'],
#  ['perfect',
#   'first',
#   'would',
#   'says',
#   '22',
#   'lisa',
#   'smiled',
#   'relaxed',
#   'know',
#   'relaxed',
#   'calm'],
#  ['well', 'smiling', 'relaxing', 'go', 'back', 'paragraph', 'twenty'],
#  ['sorry', 'twenty', 'right', 'would', 'maybe', 'read', 'relaxed', '20'],
#  ['able',
#   'actually',
#   'awesome',
#   'got',
#   'next',
#   'um',
#   'little',
#   'round',
#   'one',
#   'want',
#   'sure',
#   'continue',
#   'text',
#   'misunderstanding',
#   'asking',
#   'still'],
#  ['last', 'one'],
#  ['comfortable', 'previous'],
#  ['bet',
#   'really',
#   'know',
#   'ethan',
#   'acting',
#   'like',
#   'ethan',
#   'definitely',
#   'inaudible',
#   'wanted',
#   'really',
#   'well',
#   'keeping',
#   'great',
#   'like',
#   'really',
#   'great',
#   'like',
#   'saying',
#   'inaudible',
#   'going',
#   'along',
#   'something',
#   'else',
#   'follow',
#   'ethan',
#   'really',
#   'strong',
#   'said',
#   'tell',
#   'read',
#   'tells',
#   'feeling',
#   'actually',
#   'want',
#   'well',
#   'like',
#   'strong',
#   'expanding',
#   'important',
#   'text'],
#  ['providing',
#   'like',
#   'supportive',
#   'sharing',
#   'pulling',
#   'actually',
#   'processing',
#   'analyzing',
#   'getting'],
#  ['exactly',
#   'exactly',
#   'much',
#   'possible',
#   'want',
#   'another',
#   'give',
#   'us',
#   'text',
#   'really',
#   'important',
#   'text',
#   'helps',
#   'us',
#   'thinking',
#   'gives',
#   'us',
#   'lisa',
#   'feeling',
#   'excited',
#   'know',
#   'wrong',
#   'us',
#   'tells',
#   'helps',
#   'us',
#   'focusing',
#   'right'],
#  ['going',
#   'going',
#   'would',
#   'gave',
#   'without',
#   'using',
#   'text',
#   'going',
#   'responding',
#   'jasmine',
#   'tells',
#   'feeling',
#   'nervous',
#   'thank',
#   'using',
#   'text',
#   'know',
#   'using',
#   'text',
#   'know',
#   'great',
#   'jasmine',
#   'supports',
#   'answer',
#   'supports',
#   'getting',
#   'really',
#   'used',
#   'asking',
#   'text',
#   'going',
#   'important'],
#  ...]

# %% [markdown]
# # Generate word embeddings with Gensim's library

# %%
model = word2vec.Word2Vec(DOCS, **w2v_params)

# %% [markdown]
# # Visualize with tSNE

# %% [markdown]
# ## Get model coordinates to plot

# %%
coords = pd.DataFrame(
    dict(
        vector = [model.wv.get_vector(w) for w in model.wv.key_to_index], 
        term_str = model.wv.key_to_index.keys()
    )).set_index('term_str')

# %%
# coords

# %%
# TFM = coords.apply(lambda x: pd.Series(x.vector), 1)

# %% [markdown]
# ## Use ScikitLearn's TSNE library

# %%
tsne_engine = TSNE(perplexity=20, n_components=2, init='pca', n_iter=2500, random_state=23)
tsne_model = tsne_engine.fit_transform(coords.vector.to_list())
# Out:
# /Users/poppy/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:790: FutureWarning:
#
# The default learning rate in TSNE will change from 200.0 to 'auto' in 1.2.
#
# /Users/poppy/opt/anaconda3/lib/python3.9/site-packages/sklearn/manifold/_t_sne.py:982: FutureWarning:
#
# The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.

# %%
coords['x'] = tsne_model[:,0]
coords['y'] = tsne_model[:,1]

# %% [markdown]
# ## Add some vocab features

# %%
if coords.shape[1] == 3:
    coords = coords.merge(VOCAB.reset_index(), on='term_str')
    coords = coords.set_index('term_str')

# %%
coords = coords[coords.stop == 0]

# %%
coords
# Out:
#                                                          vector          x  \
# term_str
# like          [0.11971838, -0.07008712, -0.05955531, 0.22899...  20.752319
# going         [0.12923764, -0.026212031, -0.043982964, 0.137...   6.025471
# think         [0.11531352, -0.046753038, -0.059350356, 0.176...  -0.752450
# really        [0.11381642, -0.054221667, -0.053556327, 0.179...  19.863630
# want          [0.08789829, -0.031320177, -0.033304468, 0.148...  19.251364
# ...                                                         ...        ...
# interrupting  [0.09201156, -0.03897764, -0.03003447, 0.13068... -21.039642
# something     [0.08326203, -0.029924268, -0.035703037, 0.128... -20.421303
# focused       [0.10309715, -0.040864296, -0.041540153, 0.149... -10.998887
# found         [0.0853597, -0.027728783, -0.041656997, 0.1294... -20.366478
# knew          [0.10968017, -0.044584673, -0.041070912, 0.155... -10.802016
#
#                       y     n         p          i  n_chars max_pos  n_pos  \
# term_str
# like           1.197536  3702  0.043972   4.507255        4      IN      8
# going         -9.262965  1298  0.015418   6.019269        5     VBG      1
# think          1.500181  1856  0.022046   5.503363        5     VBP      3
# really        -0.115884  1081  0.012840   6.283193        6      RB      1
# want          -1.619846  1294  0.015370   6.023722        4     VBP      3
# ...                 ...   ...       ...        ...      ...     ...    ...
# interrupting  20.524584    33  0.000392  11.316950       12     VBG      3
# something     20.029104   505  0.005998   7.381205        9      NN      3
# focused       12.908990    30  0.000356  11.454454        7     VBN      3
# found         21.274229    31  0.000368  11.407148        5     VBD      4
# knew          12.031744    32  0.000380  11.361344        4     VBD      3
#
#                                                         cat_pos  ...  \
# term_str                                                         ...
# like          {'VBN', 'VBZ', 'IN', 'VBP', 'NN', 'RB', 'JJ', ...  ...
# going                                                   {'VBG'}  ...
# think                                       {'VB', 'VBP', 'NN'}  ...
# really                                                   {'RB'}  ...
# want                                        {'VB', 'VBP', 'NN'}  ...
# ...                                                         ...  ...
# interrupting                                {'VBG', 'NN', 'JJ'}  ...
# something                                   {'VBG', 'NN', 'JJ'}  ...
# focused                                    {'VBN', 'VBD', 'JJ'}  ...
# found                               {'VBN', 'VBP', 'NN', 'VBD'}  ...
# knew                                       {'VB', 'VBP', 'VBD'}  ...
#
#               stem_porter stem_snowball stem_lancaster    df       idf  \
# term_str
# like                 like          like            lik  1338  1.554451
# going                  go            go          going   724  2.440468
# think               think         think          think  1114  1.818780
# really             realli        realli           real   598  2.716312
# want                 want          want           want   720  2.448461
# ...                   ...           ...            ...   ...       ...
# interrupting    interrupt     interrupt      interrupt    28  7.132959
# something          someth        someth         someth   381  3.366666
# focused             focus         focus          focus    27  7.185426
# found               found         found          found    30  7.033423
# knew                 knew          knew           knew    26  7.239874
#
#               tfidf_mean    tfidf_sum  tfidf_median  tfidf_max        dfidf
# term_str
# like            0.399627  1570.532532           0.0   1.554451  2079.855701
# going           0.269174  1057.854836           0.0   2.440468  1766.898622
# think           0.324497  1275.274595           0.0   1.818780  2026.121009
# really          0.215798   848.086246           0.0   2.716312  1624.354530
# want            0.237532   933.499400           0.0   2.448461  1762.891561
# ...                  ...          ...           ...        ...          ...
# interrupting    0.024497    96.275128           0.0   7.132959   199.722843
# something       0.127329   500.402947           0.0   3.366666  1282.699902
# focused         0.017265    67.851211           0.0   7.185426   194.006505
# found           0.021760    85.517720           0.0   7.033423   211.002690
# knew            0.016002    62.889222           0.0   7.239874   188.236721
#
# [224 rows x 21 columns]

# %% [markdown]
# ## Plot the coordinates

# %% [markdown]
# ### Interpretation:
# The bottom cluster in the plot, which is centered around the word "Lisa", indicates the presence of discussions in a text-based scenario. In this particular scenario, Lisa is a character who serves as a point of reference for the student avatars, and the preservice teacher is responsible for providing constructive feedback to the students based on their perspectives of Lisa. An example of such a perspective is given in the original text, where Lisa is portrayed as being excited about her new job. The student avatars in the discussion are named Ava and Jasmine, and they are expressing their thoughts and opinions about Lisa based on the information provided in the text.
#
# In contrast, for the cluster on the right, centered around the word "Ethan", indicates off-task behaviors from Ethan, such as "Ethan is drumming", "Ethan is whistling", "Ethan plays Darth Vader"

# %%
px.scatter(coords.reset_index(), 'x', 'y', 
           text='term_str', 
           color='max_pos', 
           hover_name='term_str',
           title = 'Figure 7. Word cluster',
           size='tfidf_max',
           height=600).update_traces(
                mode='markers+text', 
                textfont=dict(color='black', size=14, family='Arial'),
                textposition='top center')
# Out:
# <div>                            <div id="0228e084-509f-4d39-a2c4-f02408b5fc73" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0228e084-509f-4d39-a2c4-f02408b5fc73")) {                    Plotly.newPlot(                        "0228e084-509f-4d39-a2c4-f02408b5fc73",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>max_pos=IN<br>x=%{x}<br>y=%{y}<br>tfidf_max=%{marker.size}<br>term_str=%{text}<extra></extra>","hovertext":["like","around","though","without"],"legendgroup":"IN","marker":{"color":"#636efa","size":[1.5544511965045078,6.416751641088956,6.239873879004877,6.582761592527885],"sizemode":"area","sizeref":0.018241143518428107,"symbol":"circle"},"mode":"markers+text","name":"IN","orientation":"v","showlegend":true,"text":["like","around","though","without"],"x":[20.7523193359375,-4.734864711761475,-13.051691055297852,7.7070631980896],"xaxis":"x","y":[1.1975356340408325,-0.22576740384101868,14.208142280578613,-6.357027053833008],"yaxis":"y","type":"scatter","textfont":{"color":"black","family":"Arial","size":14},"textposition":"top center"},{"hovertemplate":"<b>%{hovertext}</b><br><br>max_pos=VBG<br>x=%{x}<br>y=%{y}<br>tfidf_max=%{marker.size}<br>term_str=%{text}<extra></extra>","hovertext":["going","talking","asking","saying","feeling","trying","using","making","thinking","giving","looking","getting","whistling","reading","pounding","telling","drumming","sharing","working","listening","pointing","probing","focusing","redirecting","teaching","coming","happening","learning","paying","playing","providing","interrupting"],"legendgroup":"VBG","marker":{"color":"#EF553B","size":[2.440467710062764,3.6502947502133503,4.172129272369043,4.045495833838025,3.9013946078536654,4.573991382900153,4.636532848968866,4.48910248531364,4.310956977066359,4.974529312483882,4.997799091806729,5.296457407371244,5.239873879004877,5.021450359871374,5.355351096424813,5.692386083702384,6.03342300153745,6.296457407371244,6.212393142582769,6.448460500816294,6.770388595703657,6.85285075589563,4.0622331574221935,6.730860231517019,6.770388595703657,6.8110305802010025,6.85285075589563,6.239873879004877,7.296457407371244,6.940313597145969,7.082332602018397,7.132958675088365],"sizemode":"area","sizeref":0.018241143518428107,"symbol":"circle"},"mode":"markers+text","name":"VBG","orientation":"v","showlegend":true,"text":["going","talking","asking","saying","feeling","trying","using","making","thinking","giving","looking","getting","whistling","reading","pounding","telling","drumming","sharing","working","listening","pointing","probing","focusing","redirecting","teaching","coming","happening","learning","paying","playing","providing","interrupting"],"x":[6.025471210479736,12.957923889160156,-2.1104390621185303,-8.533201217651367,-4.7763261795043945,19.376998901367188,4.192837715148926,19.06438446044922,-2.170198917388916,11.67917251586914,0.13750773668289185,10.569524765014648,11.90631103515625,5.127138614654541,-2.772094249725342,10.808720588684082,11.35854721069336,2.914005994796753,8.770845413208008,-7.030389308929443,-17.306047439575195,-12.213679313659668,-4.8387675285339355,-18.07436180114746,-7.83905029296875,-15.304243087768555,-15.836505889892578,11.090475082397461,-18.09095001220703,-21.19443130493164,-16.463794708251953,-21.039642333984375],"xaxis":"x","y":[-9.262965202331543,1.720188021659851,5.525423049926758,1.471774935722351,-13.464618682861328,1.5115835666656494,-12.710103988647461,-4.01759672164917,4.370923042297363,-5.368834495544434,-1.5472259521484375,-6.567668437957764,2.8258512020111084,-6.029231071472168,-16.396347045898438,-4.978240489959717,0.6994935870170593,-10.993657112121582,-5.564990043640137,0.6199216842651367,19.973251342773438,8.66755199432373,3.0188848972320557,17.2795906066 ...

# %% [markdown]
# # Semantic Algebra

# %% [markdown]
# ## Analogies
#
# $A : B :: C : D? \rightarrow B - A + C = D$

# %%
def complete_analogy(A, B, C, n=2):
    try:
        cols = ['term', 'sim']
        return pd.DataFrame(model.wv.most_similar(positive=[B, C], negative=[A])[0:n], columns=cols)
    except KeyError as e:
        print('Error:', e)
        return None
    
def get_most_similar(positive, negative=None):
    return pd.DataFrame(model.wv.most_similar(positive, negative), columns=['term', 'sim'])

# %%
complete_analogy('ethan', 'drumming', 'lisa', 5)
# Out:
#       term       sim
# 0  feeling  0.985872
# 1     says  0.982758
# 2      lie  0.981539
# 3    pismo  0.981268
# 4  nervous  0.980813

# %%
complete_analogy('stop', 'redirecting', 'text', 5)
# Out:
#       term       sim
# 0    using  0.996231
# 1  probing  0.995938
# 2    thank  0.995526
# 3  thought  0.995360
# 4  sharing  0.995341

# %% [markdown]
# ## Similarites

# %%
print("Table 2a. Similar words for 'ethan'")
get_most_similar('ethan')
# Out:
# Table 2a. Similar words for 'ethan'
#         term       sim
# 0     making  0.998582
# 1  whistling  0.998301
# 2    talking  0.997219
# 3      quiet  0.996824
# 4       stop  0.996718
# 5   specific  0.996617
# 6    instead  0.996586
# 7       need  0.996495
# 8      darth  0.996325
# 9   drumming  0.996221

# %%
print("Table 2b. Similar words for 'lisa'")
get_most_similar('lisa')
# Out:
# Table 2b. Similar words for 'lisa'
#       term       sim
# 0  feeling  0.991205
# 1      lie  0.989978
# 2    pizmo  0.987431
# 3    pismo  0.987161
# 4   brings  0.986692
# 5  nervous  0.986241
# 6     says  0.985507
# 7  relaxed  0.985117
# 8       22  0.984527
# 9   likely  0.983045

# %%
get_most_similar('redirecting')
# Out:
#            term       sim
# 0   immediately  0.999183
# 1   necessarily  0.999170
# 2        around  0.999130
# 3        timely  0.999125
# 4  specifically  0.999112
# 5           use  0.999103
# 6      learning  0.999099
# 7       working  0.999092
# 8          real  0.999084
# 9          less  0.999076

# %%
get_most_similar('textual')
# Out:
#         term       sim
# 0      using  0.997023
# 1      wrong  0.995692
# 2    probing  0.995650
# 3       text  0.994790
# 4      thank  0.994137
# 5    sharing  0.994004
# 6    jasmine  0.993293
# 7  incorrect  0.993209
# 8    correct  0.992814
# 9        get  0.992496

# %% [markdown]
# # Save

# %%
W2V = pd.DataFrame(model.wv.get_normed_vectors(), index=model.wv.key_to_index)
W2V.to_csv('{}/W2V.csv'.format(data_out))
pd.Series(DOCS).to_csv('{}/GENSIM_DOCS.csv'.format(data_out), index=False, header=False)
